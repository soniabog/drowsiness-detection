# %% [markdown]
# # Driver fatigue detection using eye condition classification CNN model

# %% [markdown]
# **Project Goal**:
#
# Create a convolutional neural network model that classifies whether eyes are open or closed. Then use this model in a program that gives a warning message when a driver has their eyes closed for too long.

# %% [markdown]
# # Table of Contents
# 1. [CNN Model](#model_cnn)
#     1. [Importing libraries and data](#import)
#     2. [Preparing and augmenting data for model training](#przygotowanie)
#     3. [Training models and assessing their effectiveness](#trenowanie)
# 2. [Testing the model on my own dataset](#testowanie)
#     1. [My own dataset](#wlasny_zbior)
#     2. [Testing the model](#testowanie_modelu)
# 3. [Testing the model on video sequences](#testowanie_wideo)
# 4. [Proposals for further project development](#rozwoj)

# %% [markdown]
# # CNN model <a name="model_cnn"></a>

# %% [markdown]
# ## 1.1. Importing libraries and data <a name="import"></a>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import os
import cv2
import dlib
from imutils import face_utils
import time

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import tensorflow as tf
import keras
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.utils import to_categorical
from keras.src.legacy.preprocessing.image import ImageDataGenerator

# %% [markdown]
# The model was trained with images from the Kaggle dataset: https://www.kaggle.com/datasets/dheerajperumandla/drowsiness-dataset. The dataset contains 726 images of closed eyes and the same number of images of open eyes.

# %% [markdown]
# Photo labels are assigned based on the folder the photo is in: 'open' or 'closed':

# %%
labels = os.listdir("../input/photos")

# %%
labels
# Out:
# ['closed', 'open']

# %% [markdown]
# Sample photos from both categories:

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))

img0 = plt.imread("../input/photos/closed/_0.jpg")
axs[0, 0].imshow(img0)
axs[0, 0].set_title("Zamknięte 0")
axs[0, 0].axis('off')

img1 = plt.imread("../input/photos/open/_245.jpg")
axs[0, 1].imshow(img1)
axs[0, 1].set_title("Otwarte 245")
axs[0, 1].axis('off')

img2 = plt.imread("../input/photos/closed/_567.jpg")
axs[1, 0].imshow(img2)
axs[1, 0].set_title("Zamknięte 567")
axs[1, 0].axis('off')

img3 = plt.imread("../input/photos/open/_612.jpg")
axs[1, 1].imshow(img3)
axs[1, 1].set_title("Otwarte 612")
axs[1, 1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Photos shapes:

# %%
a = plt.imread("../input/photos/closed/_0.jpg")

# %%
a.shape
# Out:
# (145, 145, 3)

# %% [markdown]
# The 'get_data' function is used to load images from a specified directory and then process them into a form that can be used to train models. The images are scaled to a size of 145.

# %%
def get_data(dir_path="../input/photos/"):
    labels = ['closed', 'open']
    IMG_SIZE = 145
    data = []
    for label in labels:
        path = os.path.join(dir_path, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                data.append([resized_array, class_num])
            except Exception as e:
                print(e)
    return data

# %% [markdown]
# ## 1.2. Data preparation and augmentation for model training <a name="przygotowanie"></a>

# %% [markdown]
# Two lists 'X' are created to store images and 'y' for labels. They are filled iteratively by 'data_train':

# %%
data_train = get_data()
X = []
y = []
for feature, label in data_train:
    X.append(feature)
    y.append(label)

# %% [markdown]
# Then 'X' and 'y' are converted to numpy arrays, and 'X' is additionally transformed to dimensions corresponding to the format required by CNN models:

# %%
X = np.array(X)
X = X.reshape(-1, 145, 145, 3)

# %% [markdown]
# Data Normalization: Converting the range of 'X' values ​​from 0-255 to 0-1.

# %%
X = X / 255.0

# %%
label_bin = LabelBinarizer()
y = label_bin.fit_transform(y)

# %%
y = np.array(y)

# %% [markdown]
# The data is split into training and testing sets, where 30% of the data is used as the test set. The setting 'stratify=y' is to ensure that both sets have similar proportions of classes.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3, stratify=y)

# %% [markdown]
# Labels are transformed to a categorical format, which is required for the later use of the 'binary-crossentropy' loss function.

# %%
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

# %% [markdown]
# The use of data augmentation is intended to help increase the diversity of data through random modifications of images (changing the scale, mirroring, rotation), while the creation of data generators allows for more efficient loading and processing of data during model training.

# %%
train_generator = ImageDataGenerator(rescale=1/255, zoom_range=0.2, horizontal_flip=True, rotation_range=30)
test_generator = ImageDataGenerator(rescale=1/255)

train_generator = train_generator.flow(np.array(X_train), y_train, shuffle=False)
test_generator = test_generator.flow(np.array(X_test), y_test, shuffle=False)

# %% [markdown]
# ## 1.3. Training Models and Evaluating Their Performance <a name="trenowanie"></a>

# %% [markdown]
# ### Model 1

# %% [markdown]
# This model contains **two convolutional layers** with **32 and 64 filters** and ReLU activation function, combined with MaxPooling layers. Flatten layer transforms data into a vector, which is processed by **dense layer with 128 neurons** and dropout 0.5, to reduce the risk of overfitting. The last Dense layer with two outputs and softmax activation function is used to classify images into two classes.

# %%
input_shape = (145, 145, 3)
num_classes = 2

model_1 = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model_1.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model_1.summary()
# Out:
# C:\Users\sonia\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 143, 143, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 71, 71, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 69, 69, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 34, 34, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 73984)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       9,470,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,489,730 (36.20 MB)
#  Trainable params: 9,489,730 (36.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The training process of this model consists of running the entire training dataset through the model 50 times, this data is divided into smaller groups 'batches', where each 'batch' contains 32 examples. Test data is used for validation after each 'epoch', which allows for monitoring and evaluating the model's performance.

# %%
history_1 = model_1.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=32)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 236ms/step - accuracy: 0.6211 - loss: 1.1057 - val_accuracy: 0.8601 - val_loss: 0.2915
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9054 - loss: 0.2467 - val_accuracy: 0.9220 - val_loss: 0.1813
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9387 - loss: 0.1645 - val_accuracy: 0.9450 - val_loss: 0.1474
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 250ms/step - accuracy: 0.9430 - loss: 0.1453 - val_accuracy: 0.9564 - val_loss: 0.1293
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 238ms/step - accuracy: 0.9734 - loss: 0.0771 - val_accuracy: 0.9427 - val_loss: 0.1680
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.9671 - loss: 0.0976 - val_accuracy: 0.9541 - val_loss: 0.1485
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9725 - loss: 0.0768 - val_accuracy: 0.9587 - val_loss: 0.1420
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 246ms/step - accuracy: 0.9730 - loss: 0.0733 - val_accuracy: 0.9587 - val_loss: 0.1303
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 246ms/step - accuracy: 0.9821 - loss: 0.0499 - val_accuracy: 0.9564 - val_loss: 0.1378
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - accuracy: 0.9849 - loss: 0.0528 - val_accuracy: 0.9564 - val_loss: 0.1449
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9813 - loss: 0.0486 - val_accuracy: 0.9472 - val_loss: 0.1502
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9819 - loss: 0.0657 - val_accuracy: 0.9633 - val_loss: 0.1522
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.9930 - loss: 0.0293 - val_accuracy: 0.9381 - val_loss: 0.2303
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - accuracy: 0.9734 - loss: 0.0634 - val_accuracy: 0.9060 - val_loss: 0.3715
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 235ms/step - accuracy: 0.9713 - loss: 0.1117 - val_accuracy: 0.9427 - val_loss: 0.1644
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 237ms/step - accuracy: 0.9893 - loss: 0.0261 - val_accuracy: 0.9656 - val_loss: 0.1314
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 236ms/step - accuracy: 0.9979 - loss: 0.0200 - val_accuracy: 0.9610 - val_loss: 0.1459
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 237ms/step - accuracy: 0.9890 - loss: 0.0366 - val_accuracy: 0.9702 - val_loss: 0.1344
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9921 - loss: 0.0231 - val_accuracy: 0.9541 - val_loss: 0.1717
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 218ms/step - accuracy: 0.9962 - loss: 0.0142 - val_accuracy: 0.9633 - val_loss: 0.1360
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - accuracy: 0.9978 - loss: 0.0129 - val_accuracy: 0.9564 - val_loss: 0.1715
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 218ms/step - accuracy: 0.9949 - loss: 0.0133 - val_accuracy: 0.9518 - val_loss: 0.2343
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 241ms/step - accuracy: 0.9946 - loss: 0.0178 - val_accuracy: 0.9587 - val_loss: 0.1507
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 236ms/step - accuracy: 0.9998 - loss: 0.0066 - val_accuracy: 0.9587 - val_loss: 0.1990
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 238ms/step - accuracy: 0.9968 - loss: 0.0117 - val_accuracy: 0.9587 - val_loss: 0.2078
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9942 - loss: 0.0141 - val_accuracy: 0.9679 - val_loss: 0.1810
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 241ms/step - accuracy: 0.9988 - loss: 0.0058 - val_accuracy: 0.9610 - val_loss: 0.2038
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.9942 - loss: 0.0118 - val_accuracy: 0.9656 - val_loss: 0.1668
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 248ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9633 - val_loss: 0.2090
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9943 - loss: 0.0164 - val_accuracy: 0.9472 - val_loss: 0.1981
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - accuracy: 0.9954 - loss: 0.0117 - val_accuracy: 0.9656 - val_loss: 0.1987
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - accuracy: 0.9990 - loss: 0.0067 - val_accuracy: 0.9679 - val_loss: 0.2860
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - accuracy: 0.9877 - loss: 0.0536 - val_accuracy: 0.9450 - val_loss: 0.2319
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.9932 - loss: 0.0294 - val_accuracy: 0.9610 - val_loss: 0.1289
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.9988 - loss: 0.0221 - val_accuracy: 0.9656 - val_loss: 0.1562
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - accuracy: 0.9965 - loss: 0.0121 - val_accuracy: 0.9495 - val_loss: 0.1740
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 218ms/step - accuracy: 0.9945 - loss: 0.0140 - val_accuracy: 0.9587 - val_loss: 0.2019
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.9983 - loss: 0.0073 - val_accuracy: 0.9587 - val_loss: 0.1959
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 215ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9610 - val_loss: 0.2020
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - accuracy: 0.9987 - loss: 0.0108 - val_accuracy: 0.9472 - val_loss: 0.3591
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - accuracy: 0.9928 - loss: 0.0290 - val_accuracy: 0.9564 - val_loss: 0.2082
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 269ms/step - accuracy: 0.9976 - loss: 0.0127 - val_accuracy: 0.9541 - val_loss: 0.2443
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 268ms/step - accuracy: 0.9964 - loss: 0.0144 - val_accuracy: 0.9610 - val_loss: 0.2468
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 251ms/step - accuracy: 0.9972 - loss: 0.0117 - val_accuracy: 0.9541 - val_loss: 0.2735
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - accuracy: 0.9969 - loss: 0.0196 - val_accuracy: 0.9587 - val_loss: 0.1968
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9956 - loss: 0.0149 - val_accuracy: 0.9518 - val_loss: 0.2782
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9969 - loss: 0.0102 - val_accuracy: 0.9518 - val_loss: 0.2943
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 217ms/step - accuracy: 0.9973 - loss: 0.0103 - val_accuracy: 0.9427 - val_loss: 0.2966
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - accuracy: 0.9961 - loss: 0.0118 - val_accuracy: 0.9495 - val_loss: 0.4301
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - accuracy: 0.9932 - loss: 0.0239 - val_accuracy: 0.9656 - val_loss: 0.2485

# %% [markdown]
# **Accuracy and Loss Charts**

# %%
def plot_training_history(history):
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(accuracy))

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, accuracy, "b", label="training accuracy")
    plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
    plt.legend()
    plt.title("Training and Validation Accuracy")

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, "b", label="training loss")
    plt.plot(epochs, val_loss, "r", label="validation loss")
    plt.legend()
    plt.title("Training and Validation Loss")

    plt.show()

# %%
plot_training_history(history_1)

# %% [markdown]
# The training accuracy is close to 100%, while the validation accuracy is around 95%, which is a good result, but may suggest that the model may be slightly overfitted. The training loss gradually decreases, reaching a low level, while the validation loss oscillates around 0.2.

# %% [markdown]
# **Classification Report and Support Functions**

# %%
def prepare_image(filepath, IMG_SIZE=145):
    img_array = cv2.imread(filepath, cv2.IMREAD_COLOR)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255.0

# %%
def predict_state(filepath, model):
    prepared_image = prepare_image(filepath)
    prediction = model.predict(prepared_image)
    return prediction[0][0]

# %%
predictions = model_1.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step

# %%
report = classification_report(true_classes, predicted_classes, target_names=['open', 'closed'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         open       0.96      0.99      0.97       218
#       closed       0.99      0.95      0.97       218
#
#     accuracy                           0.97       436
#    macro avg       0.97      0.97      0.97       436
# weighted avg       0.97      0.97      0.97       436

# %% [markdown]
# Model 1 achieves high accuracy (97%) and very good recall for the 'closed' class (95%). Recall for the 'closed' class means that the model correctly identifies 95% of closed eyes, which is a good result, especially for an application where detecting closed eyes is crucial.

# %% [markdown]
# ### Model 2

# %% [markdown]
# This model contains **four convolutional layers** with increasing number of filters (**32, 64, 128, 128**), each of them follows MaxPooling operation which helps in dimensionality reduction while preserving essential features. **Dense layers with 512 units** and Dropout (0.5) minimize the risk of overfitting and softmax classifies images into two classes.

# %%
model_2 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(145, 145, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')
])

model_2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_2.summary()
# Out:
# C:\Users\sonia\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)                    │ (None, 143, 143, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 71, 71, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 69, 69, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 34, 34, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 14, 14, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 6272)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 512)                 │       3,211,776 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 2)                   │           1,026 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,453,634 (13.17 MB)
#  Trainable params: 3,453,634 (13.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The process and parameters for training this model are the same as the previous one.

# %%
history_2 = model_2.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=32)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 303ms/step - accuracy: 1.0000 - loss: 2.5797e-04 - val_accuracy: 0.9725 - val_loss: 0.4224
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 294ms/step - accuracy: 1.0000 - loss: 1.5669e-04 - val_accuracy: 0.9702 - val_loss: 0.5195
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 292ms/step - accuracy: 1.0000 - loss: 5.7330e-05 - val_accuracy: 0.9771 - val_loss: 0.4398
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 298ms/step - accuracy: 1.0000 - loss: 3.7097e-05 - val_accuracy: 0.9771 - val_loss: 0.4450
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 314ms/step - accuracy: 1.0000 - loss: 5.5114e-05 - val_accuracy: 0.9748 - val_loss: 0.4613
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 300ms/step - accuracy: 1.0000 - loss: 2.2134e-05 - val_accuracy: 0.9748 - val_loss: 0.4640
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 292ms/step - accuracy: 1.0000 - loss: 2.4339e-05 - val_accuracy: 0.9748 - val_loss: 0.4605
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 293ms/step - accuracy: 1.0000 - loss: 4.5773e-05 - val_accuracy: 0.9725 - val_loss: 0.4837
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 300ms/step - accuracy: 1.0000 - loss: 1.5679e-05 - val_accuracy: 0.9725 - val_loss: 0.4929
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 310ms/step - accuracy: 1.0000 - loss: 3.3002e-05 - val_accuracy: 0.9748 - val_loss: 0.4742
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 293ms/step - accuracy: 1.0000 - loss: 2.4712e-05 - val_accuracy: 0.9725 - val_loss: 0.4833
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 294ms/step - accuracy: 1.0000 - loss: 1.2809e-05 - val_accuracy: 0.9725 - val_loss: 0.4803
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 317ms/step - accuracy: 1.0000 - loss: 7.1327e-06 - val_accuracy: 0.9748 - val_loss: 0.4891
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 302ms/step - accuracy: 1.0000 - loss: 3.7477e-05 - val_accuracy: 0.9771 - val_loss: 0.4704
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 302ms/step - accuracy: 1.0000 - loss: 1.4934e-05 - val_accuracy: 0.9748 - val_loss: 0.4738
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 327ms/step - accuracy: 1.0000 - loss: 1.3106e-05 - val_accuracy: 0.9771 - val_loss: 0.4822
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 328ms/step - accuracy: 1.0000 - loss: 4.3646e-06 - val_accuracy: 0.9771 - val_loss: 0.4871
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 296ms/step - accuracy: 1.0000 - loss: 1.0598e-05 - val_accuracy: 0.9748 - val_loss: 0.4939
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 303ms/step - accuracy: 1.0000 - loss: 3.4717e-06 - val_accuracy: 0.9748 - val_loss: 0.4954
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 306ms/step - accuracy: 1.0000 - loss: 3.6641e-06 - val_accuracy: 0.9748 - val_loss: 0.4974
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 383ms/step - accuracy: 1.0000 - loss: 1.5512e-05 - val_accuracy: 0.9748 - val_loss: 0.4905
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 310ms/step - accuracy: 1.0000 - loss: 1.1834e-05 - val_accuracy: 0.9771 - val_loss: 0.4725
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 317ms/step - accuracy: 1.0000 - loss: 7.9801e-06 - val_accuracy: 0.9771 - val_loss: 0.4871
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 301ms/step - accuracy: 1.0000 - loss: 3.3740e-06 - val_accuracy: 0.9748 - val_loss: 0.4917
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 296ms/step - accuracy: 1.0000 - loss: 2.7408e-06 - val_accuracy: 0.9748 - val_loss: 0.4944
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 297ms/step - accuracy: 1.0000 - loss: 3.1762e-06 - val_accuracy: 0.9748 - val_loss: 0.5002
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 351ms/step - accuracy: 1.0000 - loss: 7.6749e-06 - val_accuracy: 0.9748 - val_loss: 0.5057
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 298ms/step - accuracy: 1.0000 - loss: 3.1127e-06 - val_accuracy: 0.9748 - val_loss: 0.5008
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 301ms/step - accuracy: 1.0000 - loss: 3.8094e-06 - val_accuracy: 0.9748 - val_loss: 0.5029
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 328ms/step - accuracy: 1.0000 - loss: 7.5998e-06 - val_accuracy: 0.9771 - val_loss: 0.4948
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 294ms/step - accuracy: 1.0000 - loss: 9.4194e-06 - val_accuracy: 0.9771 - val_loss: 0.4761
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 312ms/step - accuracy: 1.0000 - loss: 1.1291e-05 - val_accuracy: 0.9794 - val_loss: 0.4873
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 306ms/step - accuracy: 1.0000 - loss: 8.4295e-06 - val_accuracy: 0.9748 - val_loss: 0.4962
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 320ms/step - accuracy: 1.0000 - loss: 5.6276e-06 - val_accuracy: 0.9725 - val_loss: 0.5007
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 296ms/step - accuracy: 1.0000 - loss: 1.0070e-05 - val_accuracy: 0.9771 - val_loss: 0.4934
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 364ms/step - accuracy: 1.0000 - loss: 6.8109e-06 - val_accuracy: 0.9748 - val_loss: 0.4952
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 313ms/step - accuracy: 1.0000 - loss: 6.0125e-06 - val_accuracy: 0.9748 - val_loss: 0.4974
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 299ms/step - accuracy: 1.0000 - loss: 4.9588e-06 - val_accuracy: 0.9748 - val_loss: 0.5089
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 290ms/step - accuracy: 1.0000 - loss: 9.5591e-06 - val_accuracy: 0.9748 - val_loss: 0.5134
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 283ms/step - accuracy: 1.0000 - loss: 2.9200e-06 - val_accuracy: 0.9748 - val_loss: 0.5141
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 285ms/step - accuracy: 1.0000 - loss: 5.3398e-05 - val_accuracy: 0.9794 - val_loss: 0.4855
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 291ms/step - accuracy: 1.0000 - loss: 6.2161e-06 - val_accuracy: 0.9794 - val_loss: 0.4944
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 311ms/step - accuracy: 1.0000 - loss: 2.2225e-06 - val_accuracy: 0.9771 - val_loss: 0.4968
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 334ms/step - accuracy: 1.0000 - loss: 3.5222e-06 - val_accuracy: 0.9771 - val_loss: 0.5030
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 346ms/step - accuracy: 1.0000 - loss: 1.3693e-05 - val_accuracy: 0.9794 - val_loss: 0.4897
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 321ms/step - accuracy: 1.0000 - loss: 4.2051e-06 - val_accuracy: 0.9794 - val_loss: 0.4933
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - accuracy: 1.0000 - loss: 2.0993e-06 - val_accuracy: 0.9794 - val_loss: 0.4995
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 375ms/step - accuracy: 1.0000 - loss: 1.7496e-06 - val_accuracy: 0.9771 - val_loss: 0.5069
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 336ms/step - accuracy: 1.0000 - loss: 5.1972e-06 - val_accuracy: 0.9771 - val_loss: 0.5091
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 351ms/step - accuracy: 1.0000 - loss: 1.0240e-06 - val_accuracy: 0.9771 - val_loss: 0.5104

# %% [markdown]
# **Accuracy and Loss Charts**

# %%
plot_training_history(history_2)

# %% [markdown]
# The training accuracy after the rapid growth reaches 100%, which suggests that the model is very effective in recognizing the features of the training data. The validation accuracy after the growth remains at around 97.5%. The training loss remains low throughout the training process, so the model effectively minimizes errors on the training data. The validation loss is more variable, which suggests that there may be more difficult features in the data to learn.

# %% [markdown]
# **Classification Report**

# %%
predictions = model_2.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step

# %%
report = classification_report(true_classes, predicted_classes, target_names=['open', 'closed'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         open       0.97      0.99      0.98       218
#       closed       0.99      0.97      0.98       218
#
#     accuracy                           0.98       436
#    macro avg       0.98      0.98      0.98       436
# weighted avg       0.98      0.98      0.98       436

# %% [markdown]
# Recall for the 'closed' class is 98%, meaning that the model correctly identifies 98% of closed eye cases. In the context of monitoring driver attention, this is a key metric because high recall for closed eyes ensures that the model rarely misses cases where the eyes are closed, which can be an indicator of fatigue or sleepiness. The overall accuracy of the model is 99%, meaning that the model correctly classifies 99% of all cases in the test set.

# %% [markdown]
# The best model should be **the smallest and most effective**, so based on the results of the two previous models I decided to create an intermediate variant with **3 layers**.

# %% [markdown]
# ### Model 3

# %% [markdown]
# To speed up the model, I reduced the **Dense layer size** and the number of layers.

# %%
model_3 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(145, 145, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')
])

model_3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_3.summary()
# Out:
# C:\Users\sonia\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)                    │ (None, 143, 143, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 71, 71, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 69, 69, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 34, 34, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │       4,194,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,287,938 (16.36 MB)
#  Trainable params: 4,287,938 (16.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_3 = model_3.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=32)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 255ms/step - accuracy: 0.9979 - loss: 0.0096 - val_accuracy: 0.9633 - val_loss: 0.2583
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 237ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9679 - val_loss: 0.2361
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 243ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9679 - val_loss: 0.2468
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 238ms/step - accuracy: 1.0000 - loss: 4.1651e-04 - val_accuracy: 0.9679 - val_loss: 0.2552
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 263ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9702 - val_loss: 0.1714
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 264ms/step - accuracy: 0.9988 - loss: 0.0042 - val_accuracy: 0.9656 - val_loss: 0.2718
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 241ms/step - accuracy: 0.9959 - loss: 0.0219 - val_accuracy: 0.9702 - val_loss: 0.1523
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 242ms/step - accuracy: 0.9742 - loss: 0.0567 - val_accuracy: 0.9702 - val_loss: 0.1483
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 243ms/step - accuracy: 0.9936 - loss: 0.0185 - val_accuracy: 0.9679 - val_loss: 0.1465
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 0.9876 - loss: 0.0289 - val_accuracy: 0.9679 - val_loss: 0.2335
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - accuracy: 0.9955 - loss: 0.0289 - val_accuracy: 0.9656 - val_loss: 0.1198
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step - accuracy: 0.9963 - loss: 0.0094 - val_accuracy: 0.9725 - val_loss: 0.1641
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 268ms/step - accuracy: 0.9954 - loss: 0.0082 - val_accuracy: 0.9679 - val_loss: 0.1911
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 269ms/step - accuracy: 0.9961 - loss: 0.0136 - val_accuracy: 0.9656 - val_loss: 0.1677
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 284ms/step - accuracy: 0.9993 - loss: 0.0041 - val_accuracy: 0.9656 - val_loss: 0.2343
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 291ms/step - accuracy: 0.9977 - loss: 0.0085 - val_accuracy: 0.9679 - val_loss: 0.1796
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step - accuracy: 0.9798 - loss: 0.0376 - val_accuracy: 0.9541 - val_loss: 0.1991
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 0.9869 - loss: 0.0556 - val_accuracy: 0.9518 - val_loss: 0.1995
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 291ms/step - accuracy: 0.9810 - loss: 0.0482 - val_accuracy: 0.9610 - val_loss: 0.2040
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step - accuracy: 0.9954 - loss: 0.0100 - val_accuracy: 0.9656 - val_loss: 0.2024
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 267ms/step - accuracy: 0.9839 - loss: 0.0376 - val_accuracy: 0.9702 - val_loss: 0.2553
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 267ms/step - accuracy: 0.9972 - loss: 0.0114 - val_accuracy: 0.9656 - val_loss: 0.1468
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 272ms/step - accuracy: 0.9937 - loss: 0.0104 - val_accuracy: 0.9656 - val_loss: 0.1914
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 309ms/step - accuracy: 0.9986 - loss: 0.0044 - val_accuracy: 0.9679 - val_loss: 0.1818
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 307ms/step - accuracy: 0.9940 - loss: 0.0096 - val_accuracy: 0.9702 - val_loss: 0.2353
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 324ms/step - accuracy: 0.9972 - loss: 0.0140 - val_accuracy: 0.9656 - val_loss: 0.1582
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 336ms/step - accuracy: 0.9962 - loss: 0.0151 - val_accuracy: 0.9656 - val_loss: 0.2224
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 319ms/step - accuracy: 0.9831 - loss: 0.0257 - val_accuracy: 0.9656 - val_loss: 0.2925
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 289ms/step - accuracy: 0.9939 - loss: 0.0202 - val_accuracy: 0.9633 - val_loss: 0.2883
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 306ms/step - accuracy: 0.9954 - loss: 0.0116 - val_accuracy: 0.9702 - val_loss: 0.2414
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 302ms/step - accuracy: 0.9973 - loss: 0.0084 - val_accuracy: 0.9702 - val_loss: 0.2901
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 298ms/step - accuracy: 0.9984 - loss: 0.0057 - val_accuracy: 0.9702 - val_loss: 0.2984
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 290ms/step - accuracy: 0.9995 - loss: 0.0038 - val_accuracy: 0.9656 - val_loss: 0.3854
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 286ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9679 - val_loss: 0.4065
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step - accuracy: 0.9955 - loss: 0.0137 - val_accuracy: 0.9679 - val_loss: 0.2891
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 275ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9679 - val_loss: 0.2923
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 280ms/step - accuracy: 1.0000 - loss: 7.6831e-04 - val_accuracy: 0.9679 - val_loss: 0.3140
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 288ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9633 - val_loss: 0.3553
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step - accuracy: 1.0000 - loss: 6.1914e-04 - val_accuracy: 0.9656 - val_loss: 0.3753
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 325ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9679 - val_loss: 0.3531
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 315ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9679 - val_loss: 0.3872
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 289ms/step - accuracy: 0.9994 - loss: 8.0382e-04 - val_accuracy: 0.9679 - val_loss: 0.4348
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 290ms/step - accuracy: 0.9957 - loss: 0.0115 - val_accuracy: 0.9656 - val_loss: 0.4170
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 288ms/step - accuracy: 0.9965 - loss: 0.0069 - val_accuracy: 0.9679 - val_loss: 0.3314
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 329ms/step - accuracy: 0.9998 - loss: 0.0051 - val_accuracy: 0.9656 - val_loss: 0.3347
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 295ms/step - accuracy: 1.0000 - loss: 9.4709e-04 - val_accuracy: 0.9679 - val_loss: 0.3778
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 294ms/step - accuracy: 0.9972 - loss: 0.0027 - val_accuracy: 0.9656 - val_loss: 0.3828
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 307ms/step - accuracy: 1.0000 - loss: 8.1041e-04 - val_accuracy: 0.9679 - val_loss: 0.2901
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 294ms/step - accuracy: 0.9983 - loss: 0.0028 - val_accuracy: 0.9679 - val_loss: 0.3010
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 311ms/step - accuracy: 0.9983 - loss: 0.0067 - val_accuracy: 0.9656 - val_loss: 0.3180

# %% [markdown]
# **Accuracy and Loss Charts**

# %%
plot_training_history(history_3)

# %% [markdown]
# **Classification Report**

# %%
predictions = model_3.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step

# %%
report = classification_report(true_classes, predicted_classes, target_names=['open', 'closed'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         open       0.95      0.98      0.97       218
#       closed       0.98      0.95      0.97       218
#
#     accuracy                           0.97       436
#    macro avg       0.97      0.97      0.97       436
# weighted avg       0.97      0.97      0.97       436

# %% [markdown]
# Model 3 achieves lower recall scores for the 'closed' class compared to the previous model, but is also smaller, so it is more useful for the purposes of this project. In order to achieve better results in Model 4, I increased the size of the Dense layer.

# %% [markdown]
# ### Model 4

# %% [markdown]
# This model contains **three convolutional layers** with increasing number of filters (**32, 64, 128**), each of them follows MaxPooling operation which helps in dimensionality reduction while preserving important features. **Dense layer with 256 units** and Dropout (0.5) minimizes the risk of overfitting and softmax classifies images into two classes.

# %%
model_4 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(145, 145, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')
])

model_4.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_4.summary()
# Out:
# C:\Users\sonia\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 143, 143, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 71, 71, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 69, 69, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 34, 34, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       8,388,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             514 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,482,626 (32.36 MB)
#  Trainable params: 8,482,626 (32.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_4 = model_4.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=32)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 215ms/step - accuracy: 0.9967 - loss: 0.0078 - val_accuracy: 0.9656 - val_loss: 0.2982
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - accuracy: 0.9925 - loss: 0.0163 - val_accuracy: 0.9679 - val_loss: 0.2663
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.9949 - loss: 0.0075 - val_accuracy: 0.9633 - val_loss: 0.4101
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 217ms/step - accuracy: 1.0000 - loss: 9.9876e-04 - val_accuracy: 0.9656 - val_loss: 0.3858
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 209ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9702 - val_loss: 0.3938
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9725 - val_loss: 0.3622
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 257ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9656 - val_loss: 0.4210
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 264ms/step - accuracy: 0.9983 - loss: 0.0061 - val_accuracy: 0.9564 - val_loss: 0.5328
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 272ms/step - accuracy: 0.9955 - loss: 0.0248 - val_accuracy: 0.9679 - val_loss: 0.3063
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 0.9961 - loss: 0.0192 - val_accuracy: 0.9610 - val_loss: 0.4808
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 276ms/step - accuracy: 0.9953 - loss: 0.0158 - val_accuracy: 0.9702 - val_loss: 0.2628
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 302ms/step - accuracy: 0.9974 - loss: 0.0088 - val_accuracy: 0.9587 - val_loss: 0.2650
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 331ms/step - accuracy: 0.9995 - loss: 0.0080 - val_accuracy: 0.9679 - val_loss: 0.3312
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 355ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9702 - val_loss: 0.3474
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 314ms/step - accuracy: 0.9998 - loss: 0.0025 - val_accuracy: 0.9679 - val_loss: 0.2970
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 301ms/step - accuracy: 0.9966 - loss: 0.0120 - val_accuracy: 0.9702 - val_loss: 0.3124
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 293ms/step - accuracy: 0.9984 - loss: 0.0065 - val_accuracy: 0.9587 - val_loss: 0.3576
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 302ms/step - accuracy: 0.9879 - loss: 0.0566 - val_accuracy: 0.9656 - val_loss: 0.2002
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 322ms/step - accuracy: 0.9955 - loss: 0.0225 - val_accuracy: 0.9725 - val_loss: 0.1726
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 310ms/step - accuracy: 0.9956 - loss: 0.0158 - val_accuracy: 0.9725 - val_loss: 0.3463
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 289ms/step - accuracy: 0.9920 - loss: 0.0224 - val_accuracy: 0.9335 - val_loss: 0.8340
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - accuracy: 0.9788 - loss: 0.0979 - val_accuracy: 0.9679 - val_loss: 0.3149
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 0.9942 - loss: 0.0174 - val_accuracy: 0.9633 - val_loss: 0.3287
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 298ms/step - accuracy: 0.9986 - loss: 0.0093 - val_accuracy: 0.9656 - val_loss: 0.3952
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 299ms/step - accuracy: 0.9963 - loss: 0.0235 - val_accuracy: 0.9702 - val_loss: 0.3282
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 301ms/step - accuracy: 0.9975 - loss: 0.0072 - val_accuracy: 0.9702 - val_loss: 0.3510
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 306ms/step - accuracy: 0.9986 - loss: 0.0073 - val_accuracy: 0.9656 - val_loss: 0.4447
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 346ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.9702 - val_loss: 0.3421
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 324ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9679 - val_loss: 0.3715
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 325ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9633 - val_loss: 0.3820
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 305ms/step - accuracy: 1.0000 - loss: 4.0344e-04 - val_accuracy: 0.9633 - val_loss: 0.3998
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 309ms/step - accuracy: 1.0000 - loss: 4.0704e-04 - val_accuracy: 0.9633 - val_loss: 0.3956
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 297ms/step - accuracy: 1.0000 - loss: 3.9201e-04 - val_accuracy: 0.9679 - val_loss: 0.4122
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 351ms/step - accuracy: 1.0000 - loss: 7.1849e-05 - val_accuracy: 0.9679 - val_loss: 0.4135
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 331ms/step - accuracy: 0.9999 - loss: 3.2698e-04 - val_accuracy: 0.9633 - val_loss: 0.3994
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 313ms/step - accuracy: 0.9985 - loss: 0.0046 - val_accuracy: 0.9610 - val_loss: 0.4391
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 290ms/step - accuracy: 0.9994 - loss: 0.0041 - val_accuracy: 0.9748 - val_loss: 0.4179
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 289ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9702 - val_loss: 0.4187
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 300ms/step - accuracy: 1.0000 - loss: 2.2181e-04 - val_accuracy: 0.9702 - val_loss: 0.4129
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step - accuracy: 1.0000 - loss: 2.7568e-04 - val_accuracy: 0.9702 - val_loss: 0.4142
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 303ms/step - accuracy: 1.0000 - loss: 1.7471e-04 - val_accuracy: 0.9702 - val_loss: 0.4174
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 324ms/step - accuracy: 1.0000 - loss: 6.7936e-05 - val_accuracy: 0.9702 - val_loss: 0.4223
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 302ms/step - accuracy: 1.0000 - loss: 1.7390e-04 - val_accuracy: 0.9702 - val_loss: 0.4086
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 303ms/step - accuracy: 1.0000 - loss: 6.1333e-05 - val_accuracy: 0.9702 - val_loss: 0.4165
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 317ms/step - accuracy: 1.0000 - loss: 7.9930e-05 - val_accuracy: 0.9679 - val_loss: 0.4235
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 294ms/step - accuracy: 1.0000 - loss: 2.4230e-05 - val_accuracy: 0.9679 - val_loss: 0.4235
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 285ms/step - accuracy: 1.0000 - loss: 1.8299e-05 - val_accuracy: 0.9679 - val_loss: 0.4257
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 337ms/step - accuracy: 1.0000 - loss: 6.4632e-05 - val_accuracy: 0.9679 - val_loss: 0.4291
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 297ms/step - accuracy: 1.0000 - loss: 1.1483e-04 - val_accuracy: 0.9702 - val_loss: 0.4440
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 1.0000 - loss: 1.5304e-05 - val_accuracy: 0.9702 - val_loss: 0.4403

# %% [markdown]
# **Accuracy and Loss Charts**

# %%
plot_training_history(history_4)

# %% [markdown]
# The training accuracy is very high, hovering around 99%. This indicates that the model learns the training data effectively, with one drop, possibly due to a problematic case of the training data. The validation accuracy is less stable and generally lower, which may indicate a sensitive response to new data. The training loss is low and stable, while the validation loss shows significant variability and several distinct peaks, which may also indicate subtle issues with model instability during validation.

# %% [markdown]
# **Classification Report**

# %%
predictions = model_4.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step

# %%
report = classification_report(true_classes, predicted_classes, target_names=['open', 'closed'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         open       0.96      0.99      0.97       218
#       closed       0.99      0.95      0.97       218
#
#     accuracy                           0.97       436
#    macro avg       0.97      0.97      0.97       436
# weighted avg       0.97      0.97      0.97       436

# %% [markdown]
# Model 4 has the same accuracy (97%) and recall for the 'closed' class as Model 3. However, recall for the 'open' class is higher (99%). Model 4 also has fewer layers than Model 2, which has the best results, so it may be better suited for faster performance in eye classification from video sequences.

# %% [markdown]
# ### Model Comparison

# %% [markdown]
# I compared the models in the form of a table containing the most important results of model training, i.e. recall for the 'closed' class and accuracy.

# %%
def get_metrics(model, X_test, y_test):
    predictions = model.predict(X_test)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = np.argmax(y_test, axis=1)
    report = classification_report(true_classes, predicted_classes, target_names=['open', 'closed'], output_dict=True)
    return report['accuracy'], report['closed']['recall']

# %%
accuracy_1, recall_closed_1 = get_metrics(model_1, X_test, y_test)
accuracy_2, recall_closed_2 = get_metrics(model_2, X_test, y_test)
accuracy_3, recall_closed_3 = get_metrics(model_3, X_test, y_test)
accuracy_4, recall_closed_4 = get_metrics(model_4, X_test, y_test)

results_df = pd.DataFrame({
    "Model": ["Model 1", "Model 2", "Model 3", "Model 4"],
    "Accuracy": [accuracy_1, accuracy_2, accuracy_3, accuracy_4],
    "Recall (closed)": [recall_closed_1, recall_closed_2, recall_closed_3, recall_closed_4]
})

results_df
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
#      Model  Accuracy  Recall (closed)
# 0  Model 1  0.965596         0.958716
# 1  Model 2  0.977064         0.967890
# 2  Model 3  0.965596         0.949541
# 3  Model 4  0.970183         0.954128

# %% [markdown]
# The best parameters, taking into account the model size and classification results, are shown by model 4. The model's effectiveness in classifying open and closed eyes is accurate, with very high precision and reproduction, and the number of layers is the most optimal among the tested solutions. Therefore, this model is saved and used in the further implementation of the project.

# %%
model_4.save("model_4.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## 2.Testing the model on my own dataset <a name="testowanie"></a>

# %% [markdown]
# ## 2.1. My own dataset <a name="wlasny_zbior"></a>

# %% [markdown]
# To test the chosen model, I created my own dataset. I recorded 10 people who imitated the behavior of a tired driver and closed their eyes for longer periods of time. Then I wrote a script that saved every second of video frames as photos to a selected folder.

# %% [markdown]
# *In order to maintain the privacy of people involved in my project, the dataset I created is not shown or attached to the remote repository*

# %%
folder_open = "../output/captured_frames/open"
folder_closed = "../output/captured_frames/closed"

num_files_open = len([name for name in os.listdir(folder_open) if os.path.isfile(os.path.join(folder_open, name))])
print(f"Liczba zdjęć w folderze 'open': {num_files_open}")

num_files_closed = len([name for name in os.listdir(folder_closed) if os.path.isfile(os.path.join(folder_closed, name))])
print(f"Liczba zdjęć w folderze 'closed': {num_files_closed}")
# Out:
# Liczba zdjęć w folderze 'open': 467
# Liczba zdjęć w folderze 'closed': 438

# %%
def capture_frames(video_path, output_folder, interval_seconds):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Can't open video stream or file.")
        return

    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_interval = int(fps * interval_seconds)

    frame_count = 0
    saved_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        if frame_count % frame_interval == 0:
            img_path = os.path.join(output_folder, f"frame_{saved_count}.jpg")
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            pil_image = Image.fromarray(image)
            pil_image.save(img_path)
            saved_count += 1

        frame_count += 1

    cap.release()
    print(f"{saved_count} photos saved.")

video_path = 'path_to_video'
output_folder = 'path_to_output_folder'
interval_seconds = 1

capture_frames(video_path, output_folder, interval_seconds)

# %% [markdown]
# I divided the frames cut from the films into those with open or closed eyes and placed them in appropriately named folders.

# %%
labels_2 = os.listdir("../output/captured_frames")
labels
# Out:
# ['closed', 'open']

# %%
get_data('../output/captured_frames')
# Out:
# [[array([[[148, 179, 182],
#           [155, 186, 189],
#           [151, 182, 185],
#           ...,
#           [109, 123, 122],
#           [109, 123, 122],
#           [109, 123, 122]],
#
#          [[184, 215, 218],
#           [183, 213, 216],
#           [175, 206, 209],
#           ...,
#           [109, 123, 122],
#           [109, 123, 122],
#           [109, 123, 122]],
#
#          [[135, 166, 169],
#           [123, 154, 157],
#           [148, 179, 182],
#           ...,
#           [108, 125, 122],
#           [112, 126, 124],
#           [109, 123, 122]],
#
#          ...,
#
#          [[ 35,  62,  82],
#           [ 34,  61,  81],
#           [ 33,  62,  77],
#           ...,
#           [ 12,  59, 104],
#           [ 12,  57, 108],
#           [ 14,  56, 109]],
#
#          [[ 35,  62,  82],
#           [ 34,  61,  81],
#           [ 32,  61,  77],
#           ...,
#           [ 12,  55, 100],
#           [  8,  54, 101],
#           [ 12,  56, 105]],
#
#          [[ 34,  61,  81],
#           [ 33,  58,  78],
#           [ 36,  59,  74],
#           ...,
#           [ 18,  55, 100],
#           [ 11,  56, 100],
#           [  8,  54, 101]]], dtype=uint8),
#   0],
#  [array([[[123, 154, 156],
#           [116, 147, 150],
#           [122, 151, 156],
#           ...,
#           [109, 123, 126],
#           [110, 122, 126],
#           [ 98, 118, 119]],
#
#          [[136, 167, 170],
#           [133, 164, 167],
#           [129, 159, 160],
#           ...,
#           [110, 122, 122],
#           [108, 122, 121],
#           [109, 123, 125]],
#
#          [[138, 168, 173],
#           [138, 167, 172],
#           [132, 163, 166],
#           ...,
#           [109, 122, 124],
#           [108, 122, 121],
#           [108, 122, 121]],
#
#          ...,
#
#          [[ 28,  52,  72],
#           [ 28,  52,  72],
#           [ 26,  50,  71],
#           ...,
#           [  8,  58, 118],
#           [ 10,  57, 118],
#           [ 11,  58, 119]],
#
#          [[ 28,  52,  72],
#           [ 28,  52,  72],
#           [ 26,  50,  72],
#           ...,
#           [  8,  59, 118],
#           [  9,  56, 117],
#           [ 11,  57, 119]],
#
#          [[ 28,  52,  72],
#           [ 28,  52,  72],
#           [ 30,  54,  74],
#           ...,
#           [  9,  59, 119],
#           [  7,  54, 115],
#           [  6,  53, 114]]], dtype=uint8),
#   0],
#  [array([[[145, 170, 196],
#           [145, 170, 196],
#           [147, 172, 198],
#           ...,
#           [149, 185, 203],
#           [149, 185, 203],
#           [149, 185, 203]],
#
#          [[145, 170, 196],
#           [145, 170, 196],
#           [147, 172, 198],
#           ...,
#           [149, 185, 203],
#           [149, 185, 203],
#           [149, 185, 203]],
#
#          [[145, 170, 196],
#           [145, 170, 196],
#           [147, 172, 198],
#           ...,
#           [149, 185, 203],
#           [149, 185, 203],
#           [149, 185, 203]],
#
#          ...,
#
#          [[ 21,  29,  58],
#           [ 15,  29,  58],
#           [ 21,  34,  66],
#           ...,
#           [ 97, 126, 147],
#           [ 92, 121, 142],
#           [ 88, 117, 138]],
#
#          [[ 18,  20,  46],
#           [ 17,  28,  55],
#           [ 14,  25,  55],
#           ...,
#           [ 96, 125, 146],
#           [ 91, 120, 141],
#           [ 88, 117, 137]],
#
#          [[ 21,  21,  44],
#           [ 19,  28,  52],
#           [ 15,  26,  54],
#           ...,
#           [ 95, 125, 145],
#           [ 90, 119, 140],
#           [ 87, 115, 137]]], dtype=uint8),
#   0],
#  [array([[[149, 176, 202],
#           [149, 176, 202],
#           [151, 178, 204],
#           ...,
#           [157, 193, 211],
#           [157, 193, 211],
#           [157, 193, 211]],
#
#          [[149, 176, 202],
#           [149, 176, 202],
#           [151, 178, 204],
#           ...,
#           [157, 193, 211],
#           [157, 193, 211],
#           [157, 193, 211]],
#
#          [[149, 176, 202],
#           [149, 176, 202],
#           [152, 178, 205],
#           ...,
#           [157, 193, 211],
#           [157, 193, 211],
#           [157, 193, 211]],
#
#          ...,
#
#          [[136, 162, 189],
#           [134, 161, 188],
#           [134, 161, 188],
#           ...,
#           [105, 139, 162],
#           [104, 138, 161],
#           [ 99, 133, 156]],
#
#          [[132, 159, 186],
#           [135, 162, 189],
#           [133, 160, 187],
#           ...,
#           [105, 139, 162],
#           [102, 136, 159],
#           [ 98, 132, 155]],
#
#          [[ 91, 118, 145],
#           [127, 154, 181],
#           [132, 159, 186],
#           ...,
#           [105, 139, 162],
#           [100, 134, 157],
#           [ 98, 132, 155]]], dtype=uint8),
#   0],
#  [array([[[152, 177, 203],
#           [155, 180, 206],
#           [154, 179, 205],
#           ...,
#           [162, 199, 219],
#           [163, 200, 220],
#           [163, 200, 220]],
#
#          [[153, 178, 204],
#           [155, 180, 206],
#           [155, 180, 206],
#           ...,
#           [162, 199, 219],
#           [163, 200, 220],
#           [163, 200, 220]],
#
#          [[155, 180, 206],
#           [155, 180, 206],
#           [156, 181, 207],
#           ...,
#           [162, 199, 219],
#           [163, 200, 220],
#           [163, 200, 220]],
#
#          ...,
#
#          [[117, 138, 165],
#           [117, 138, 165],
#           [116, 137, 164],
#           ...,
#           [109, 140, 163],
#           [105, 136, 159],
#           [101, 132, 155]],
#
#          [[116, 137, 164],
#           [116, 137, 164],
#           [116, 137, 164],
#           ...,
#           [106, 137, 160],
#           [103, 134, 157],
#           [ 99, 130, 153]],
#
#          [[115, 136, 163],
#           [115, 136, 163],
#           [116, 137, 164],
#           ...,
#           [104, 135, 158],
#           [102, 133, 156],
#           [ 97, 128, 151]]], dtype=uint8),
#   0],
#  [array([[[133, 165, 168],
#           [138, 169, 172],
#           [132, 163, 166],
#           ...,
#           [111, 125, 124],
#           [111, 125, 124],
#           [112, 126, 125]],
#
#          [[140, 171, 174],
#           [138, 169, 172],
#           [135, 167, 170],
#           ...,
#           [110, 124, 123],
#           [111, 125, 124],
#           [111, 125, 124]],
#
#          [[166, 195, 201],
#           [142, 172, 177],
#           [142, 172, 177],
#           ...,
#           [111, 125, 124],
#           [111, 125, 124],
#           [110, 124, 123]],
#
#          ...,
#
#          [[ 31,  53,  78],
#           [ 30,  54,  78],
#           [ 29,  53,  77],
#           ...,
#           [  8,  57, 119],
#           [  8,  57, 119],
#           [ 11,  58, 119]],
#
#          [[ 31,  53,  78],
#           [ 30,  54,  78],
#           [ 29,  53,  77],
#           ...,
#           [  9,  58, 120],
#           [ 10,  54, 117],
#           [  7,  54, 115]],
#
#          [[ 30,  52,  77],
#           [ 30,  52,  77],
#           [ 31,  53,  78],
#           ...,
#           [ 16,  61, 118],
#           [ 12,  58, 116],
#           [ 10,  57, 119]]], dtype=uint8),
#   0],
#  [array([[[149, 176, 202],
#           [149, 176, 202],
#           [151, 178, 204],
#           ...,
#           [164, 200, 218],
#           [164, 200, 218],
#           [166, 202, 220]],
#
#          [[149, 176, 202],
#           [149, 176, 202],
#           [150, 178, 204],
#           ...,
#           [164, 200, 218],
#           [164, 200, 218],
#           [166, 202, 220]],
#
#          [[149, 176, 202],
#           [149, 176, 202],
#           [150, 177, 203],
#           ...,
#           [164, 200, 218],
#           [164, 200, 218],
#           [166, 202, 220]],
#
#          ...,
#
#          [[116, 141, 167],
#           [116, 141, 167],
#           [115, 141, 167],
#           ...,
#           [109, 140, 163],
#           [106, 137, 160],
#           [101, 132, 156]],
#
#          [[115, 140, 166],
#           [115, 140, 166],
#           [115, 140, 166],
#           ...,
#           [108, 139, 162],
#           [104, 135, 158],
#           [100, 131, 154]],
#
#          [[114, 139, 165],
#           [114, 139, 165],
#           [114, 139, 165],
#           ...,
#           [106, 137, 160],
#           [103, 134, 157],
#           [ 98, 129, 152]]], dtype=uint8),
#   0],
#  [array([[[146, 173, 199],
#           [146, 173, 199],
#           [147, 174, 200],
#           ...,
#           [154, 190, 208],
#           [156, 192, 210],
#           [156, 192, 210]],
#
#          [[146, 173, 199],
#           [146, 173, 199],
#           [147, 174, 200],
#           ...,
#           [154, 190, 208],
#           [156, 192, 210],
#           [156, 192, 210]],
#
#          [[146, 173, 199],
#           [146, 173, 199],
#           [147, 174, 200],
#           ...,
#           [154, 190, 208],
#           [156, 192, 210],
#           [156, 192, 210]],
#
#          ...,
#
#          [[ 45,  66,  95],
#           [ 49,  72, 101],
#           [ 68,  96, 123],
#           ...,
#           [100, 128, 152],
#           [ 98, 126, 150],
#           [ 94, 122, 146]],
#
#          [[ 20,  36,  68],
#           [ 34,  53,  84],
#           [ 42,  63,  94],
#           ...,
#           [ 99, 127, 151],
#           [ 97, 125, 149],
#           [ 93, 122, 146]],
#
#          [[ 10,  20,  54],
#           [ 22,  34,  68],
#           [ 27,  43,  76],
#           ...,
#           [ 98, 126, 150],
#           [ 96, 124, 148],
#           [ 93, 121, 145]]], dtype=uint8),
#   0],
#  [array([[[150, 178, 202],
#           [150, 178, 202],
#           [151, 179, 204],
#           ...,
#           [145, 176, 197],
#           [147, 178, 199],
#           [147, 178, 199]],
#
#          [[150, 178, 202],
#           [150, 178, 202],
#           [151, 179, 204],
#           ...,
#           [145, 176, 197],
#           [147, 178, 199],
#           [147, 178, 199]],
#
#          [[150, 178, 202],
#           [150, 178, 202],
#           [152, 179, 203],
#           ...,
#           [145, 176, 197],
#           [147, 178, 199],
#           [147, 178, 199]],
#
#          ...,
#
#          [[114, 135, 164],
#           [111, 133, 161],
#           [112, 133, 162],
#           ...,
#           [ 94, 122, 146],
#           [ 91, 119, 143],
#           [ 89, 117, 141]],
#
#          [[ 67,  88, 119],
#           [ 98, 119, 150],
#           [112, 133, 164],
#           ...,
#           [ 93, 121, 145],
#           [ 90, 118, 142],
#           [ 88, 116, 140]],
#
#          [[ 37,  58,  90],
#           [ 45,  66,  98],
#           [ 77,  99, 130],
#           ...,
#           [ 92, 120, 144],
#           [ 88, 116, 140],
#           [ 87, 115, 139]]], dtype=uint8),
#   0],
#  [array([[[141, 165, 189],
#           [141, 165, 189],
#           [142, 166, 190],
#           ...,
#           [146, 177, 198],
#           [147, 178, 199],
#           [150, 181, 202]],
#
#          [[142, 166, 190],
#           [142, 166, 190],
#           [143, 167, 191],
#           ...,
#           [146, 177, 198],
#           [148, 179, 200],
#           [151, 182, 203]],
#
#          [[143, 167, 191],
#           [143, 167, 191],
#           [143, 167, 191],
#           ...,
#           [146, 177, 198],
#           [149, 180, 201],
#           [152, 183, 204]],
#
#          ...,
#
#          [[111, 134, 160],
#           [106, 129, 155],
#           [109, 132, 158],
#           ...,
#           [ 89, 116, 136],
#           [ 88, 115, 135],
#           [ 87, 114, 135]],
#
#          [[106, 129, 155],
#           [107, 130, 156],
#           [109, 132, 158],
#           ...,
#           [ 89, 116, 136],
#           [ 87, 114, 134],
#           [ 87, 114, 133]],
#
#          [[ 56,  79, 105],
#           [ 97, 120, 146],
#           [109, 132, 158],
#           ...,
#           [ 89, 116, 136],
#           [ 87, 114, 134],
#           [ 86, 113, 133]]], dtype=uint8),
#   0],
#  [array([[[143, 167, 191],
#           [145, 169, 193],
#           [146, 170, 194],
#           ...,
#           [149, 180, 201],
#           [151, 182, 203],
#           [153, 184, 205]],
#
#          [[143, 167, 191],
#           [145, 169, 193],
#           [146, 170, 194],
#           ...,
#           [150, 181, 202],
#           [151, 182, 203],
#           [153, 184, 205]],
#
#          [[143, 167, 191],
#           [145, 169, 193],
#           [146, 170, 194],
#           ...,
#           [150, 181, 202],
#           [151, 182, 203],
#           [153, 184, 205]],
#
#          ...,
#
#          [[111, 132, 159],
#           [109, 130, 157],
#           [110, 131, 158],
#           ...,
#           [ 88, 117, 138],
#           [ 89, 116, 137],
#           [ 89, 113, 135]],
#
#          [[110, 131, 158],
#           [110, 131, 158],
#           [110, 131, 158],
#           ...,
#           [ 87, 116, 137],
#           [ 88, 115, 136],
#           [ 88, 112, 134]],
#
#          [[ 83, 104, 131],
#           [109, 130, 157],
#           [110, 131, 158],
#           ...,
#           [ 87, 116, 137],
#           [ 87, 114, 135],
#           [ 88, 111, 133]]], dtype=uint8),
#   0],
#  [array([[[141, 166, 192],
#           [143, 168, 194],
#           [144, 169, 195],
#           ...,
#           [140, 171, 192],
#           [144, 175, 196],
#           [146, 177, 198]],
#
#          [[141, 166, 192],
#           [143, 168, 194],
#           [144, 169, 195],
#           ...,
#           [140, 171, 192],
#           [144, 175, 196],
#           [146, 177, 198]],
#
#          [[141, 166, 192],
#           [143, 168, 194],
#           [144, 169, 195],
#           ...,
#           [140, 171, 192],
#           [144, 175, 196],
#           [146, 177, 198]],
#
#          ...,
#
#          [[112, 135, 161],
#           [112, 135, 161],
#           [110, 133, 159],
#           ...,
#           [ 87, 114, 135],
#           [ 87, 114, 135],
#           [ 85, 112, 133]],
#
#          [[111, 134, 160],
#           [111, 134, 160],
#           [110, 133, 159],
#           ...,
#           [ 87, 114, 135],
#           [ 86, 113, 134],
#           [ 84, 111, 132]],
#
#          [[110, 133, 159],
#           [110, 133, 159],
#           [110, 133, 159],
#           ...,
#           [ 86, 113, 134],
#           [ 85, 112, 133],
#           [ 83, 110, 132]]], dtype=uint8),
#   0],
#  [array([[[107, 120, 152],
#           [107, 120, 152],
#           [108, 121, 153],
#           ...,
#           [140, 171, 204],
#           [140, 171, 204],
#           [140, 171, 204]],
#
#          [[107, 120, 152],
#           [107, 120, 152],
#           [108, 121, 153],
#           ...,
#           [140, 171, 204],
#           [140, 171, 204],
#           [140, 171, 204]],
#
#          [[107, 120, 152],
#           [107, 120, 152],
#           [109, 122, 154],
#           ...,
#           [140, 171, 204],
#           [140, 171, 204],
#           [140, 171, 204]],
#
#          ...,
#
#          [[135, 169, 212],
#           [132, 166, 209],
#           [130, 164, 207],
#           ...,
#           [ 42,  72,  73],
#           [ 43,  68,  70],
#           [ 47,  72,  74]],
#
#          [[136, 171, 214],
#           [136, 171, 214],
#           [130, 164, 207],
#           ...,
#           [ 68,  98,  99],
#           [ 68,  93,  95],
#           [ 70,  95,  97]],
#
#          [[130, 167, 209],
#           [134, 171, 213],
#           [133, 168, 211],
#           ...,
#           [ 47,  75,  76],
#           [ 46,  71,  73],
#           [ 44,  69,  71]]], dtype=uint8),
#   0],
#  [array([[[104, 122, 151],
#           [103, 121, 150],
#           [106, 121, 153],
#           ...,
#           [140, 171, 204],
#           [140, 171, 204],
#           [140, 171, 204]],
#
#          [[104, 122, 151],
#           [103, 121, 150],
#           [106, 121, 153],
#           ...,
#           [140, 171, 204],
#           [140, 171, 204],
#           [140, 171, 204]],
#
#          [[103, 121, 150],
#           [103, 121, 150],
#           [107, 122, 154],
#           ...,
#           [140, 171, 204],
#           [140, 171, 204],
#           [140, 171, 204]],
#
#          ...,
#
#          [[137, 171, 214],
#           [135, 169, 212],
#           [133, 168, 208],
#           ...,
#           [ 68,  96,  97],
#           [ 67,  95,  96],
#           [ 60,  88,  89]],
#
#          [[138, 173, 216],
#           [137, 172, 215],
#           [135, 171, 211],
#           ...,
#           [ 46,  74,  75],
#           [ 53,  81,  82],
#           [ 49,  77,  78]],
#
#          [[135, 172, 214],
#           [135, 172, 214],
#           [132, 170, 209],
#           ...,
#           [ 62,  90,  91],
#           [ 57,  85,  86],
#           [ 60,  88,  89]]], dtype=uint8),
#   0],
#  [array([[[107, 120, 152],
#           [107, 120, 152],
#           [109, 122, 154],
#           ...,
#           [138, 169, 202],
#           [138, 169, 202],
#           [138, 169, 202]],
#
#          [[107, 120, 152],
#           [107, 120, 152],
#           [109, 122, 154],
#           ...,
#           [138, 169, 202],
#           [138, 169, 202],
#           [138, 169, 202]],
#
#          [[108, 121, 153],
#           [107, 120, 152],
#           [107, 120, 152],
#           ...,
#           [138, 169, 202],
#           [138, 169, 202],
#           [138, 169, 202]],
#
#          ...,
#
#          [[138, 171, 216],
#           [136, 169, 214],
#           [131, 165, 208],
#           ...,
#           [ 71,  99, 100],
#           [ 66,  94,  95],
#           [ 63,  91,  92]],
#
#          [[138, 172, 215],
#           [136, 170, 213],
#           [133, 167, 210],
#           ...,
#           [ 47,  75,  76],
#           [ 49,  77,  78],
#           [ 51,  79,  80]],
#
#          [[136, 171, 212],
#           [134, 169, 210],
#           [135, 169, 212],
#           ...,
#           [ 65,  93,  94],
#           [ 62,  90,  91],
#           [ 62,  90,  91]]], dtype=uint8),
#   0],
#  [array([[[109, 122, 154],
#           [109, 122, 154],
#           [109, 122, 154],
#           ...,
#           [141, 173, 202],
#           [141, 172, 205],
#           [141, 172, 205]],
#
#          [[109, 122, 154],
#           [109, 122, 154],
#           [109, 122, 154],
#           ...,
#           [141, 173, 202],
#           [141, 172, 205],
#           [141, 172, 205]],
#
#          [[108, 121, 153],
#           [108, 121, 153],
#           [109, 122, 154],
#           ...,
#           [141, 173, 202],
#           [140, 171, 204],
#           [141, 172, 205]],
#
#          ...,
#
#          [[142, 176, 219],
#           [139, 173, 216],
#           [140, 169, 213],
#           ...,
#           [ 64,  92,  96],
#           [ 69,  88,  91],
#           [ 62,  81,  85]],
#
#          [[142, 174, 215],
#           [142, 174, 216],
#           [138, 170, 211],
#           ...,
#           [ 69,  96, 100],
#           [ 72,  95,  97],
#           [ 60,  83,  85]],
#
#          [[140, 172, 212],
#           [140, 171, 211],
#           [138, 171, 210],
#           ...,
#           [ 45,  75,  78],
#           [ 47,  76,  77],
#           [ 50,  79,  80]]], dtype=uint8),
#   0],
#  [array([[[120, 134, 170],
#           [119, 133, 169],
#           [122, 136, 172],
#           ...,
#           [132, 161, 192],
#           [133, 160, 194],
#           [133, 160, 194]],
#
#          [[120, 134, 170],
#           [119, 133, 169],
#           [122, 136, 172],
#           ...,
#           [132, 161, 192],
#           [133, 160, 194],
#           [133, 160, 194]],
#
#          [[119, 133, 169],
#           [119, 133, 169],
#           [121, 135, 171],
#           ...,
#           [132, 161, 192],
#           [133, 160, 194],
#           [133, 160, 194]],
#
#          ...,
#
#          [[134, 169, 212],
#           [131, 166, 209],
#           [138, 170, 213],
#           ...,
#           [ 68,  93,  95],
#           [ 69,  92,  94],
#           [ 64,  87,  89]],
#
#          [[135, 170, 211],
#           [131, 167, 207],
#           [135, 167, 210],
#           ...,
#           [ 50,  75,  77],
#           [ 53,  76,  78],
#           [ 49,  72,  74]],
#
#          [[131, 167, 206],
#           [127, 164, 203],
#           [132, 166, 209],
#           ...,
#           [ 78, 103, 105],
#           [ 64,  87,  89],
#           [ 55,  78,  80]]], dtype=uint8),
#   0],
#  [array([[[118, 133, 165],
#           [118, 133, 165],
#           [120, 135, 167],
#           ...,
#           [129, 160, 193],
#           [131, 160, 191],
#           [131, 160, 191]],
#
#          [[118, 133, 165],
#           [118, 133, 165],
#           [118, 133, 165],
#           ...,
#           [129, 160, 193],
#           [131, 160, 191],
#           [131, 160, 191]],
#
#          [[118, 133, 165],
#           [117, 132, 164],
#           [118, 133, 165],
#           ...,
#           [129, 160, 193],
#           [131, 160, 191],
#           [131, 160, 191]],
#
#          ...,
#
#          [[132, 169, 213],
#           [137, 170, 215],
#           [138, 170, 213],
#           ...,
#           [ 53,  78,  80],
#           [ 54,  76,  81],
#           [ 54,  76,  81]],
#
#          [[136, 169, 214],
#           [135, 168, 213],
#           [137, 171, 214],
#           ...,
#           [ 65,  88,  90],
#           [ 60,  81,  85],
#           [ 59,  79,  84]],
#
#          [[139, 171, 215],
#           [136, 169, 214],
#           [134, 168, 211],
#           ...,
#           [ 52,  74,  76],
#           [ 51,  70,  75],
#           [ 52,  71,  76]]], dtype=uint8),
#   0],
#  [array([[[111, 126, 158],
#           [112, 127, 159],
#           [111, 126, 158],
#           ...,
#           [130, 160, 189],
#           [130, 160, 189],
#           [130, 160, 189]],
#
#          [[111, 126, 158],
#           [112, 127, 159],
#           [111, 126, 158],
#           ...,
#           [130, 160, 189],
#           [130, 160, 189],
#           [130, 160, 189]],
#
#          [[111, 126, 158],
#           [111, 126, 158],
#           [111, 126, 158],
#           ...,
#           [130, 160, 189],
#           [130, 160, 189],
#           [130, 160, 189]],
#
#          ...,
#
#          [[137, 172, 216],
#           [137, 172, 216],
#           [140, 174, 217],
#           ...,
#           [ 53,  76,  78],
#           [ 46,  71,  73],
#           [ 46,  71,  73]],
#
#          [[136, 171, 215],
#           [136, 171, 215],
#           [136, 170, 213],
#           ...,
#           [ 63,  84,  86],
#           [ 61,  84,  86],
#           [ 64,  87,  89]],
#
#          [[135, 170, 214],
#           [134, 169, 213],
#           [135, 169, 212],
#           ...,
#           [ 58,  79,  81],
#           [ 51,  73,  75],
#           [ 53,  75,  77]]], dtype=uint8),
#   0],
#  [array([[[116, 131, 163],
#           [116, 131, 163],
#           [118, 133, 165],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          [[116, 131, 163],
#           [116, 131, 163],
#           [118, 133, 165],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          [[115, 130, 162],
#           [116, 131, 163],
#           [118, 133, 165],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          ...,
#
#          [[136, 169, 214],
#           [138, 171, 216],
#           [138, 173, 217],
#           ...,
#           [ 68,  89,  91],
#           [ 66,  87,  91],
#           [ 51,  80,  77]],
#
#          [[134, 169, 212],
#           [134, 169, 212],
#           [136, 171, 215],
#           ...,
#           [ 47,  67,  72],
#           [ 50,  70,  75],
#           [ 45,  71,  71]],
#
#          [[132, 169, 210],
#           [130, 167, 208],
#           [134, 169, 213],
#           ...,
#           [ 62,  81,  88],
#           [ 65,  82,  90],
#           [ 62,  83,  86]]], dtype=uint8),
#   0],
#  [array([[[116, 131, 163],
#           [116, 131, 163],
#           [116, 130, 166],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          [[116, 131, 163],
#           [116, 131, 163],
#           [116, 131, 164],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          [[115, 130, 162],
#           [115, 130, 162],
#           [115, 130, 163],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          ...,
#
#          [[137, 173, 212],
#           [138, 171, 216],
#           [137, 172, 216],
#           ...,
#           [ 58,  83,  85],
#           [ 60,  81,  83],
#           [ 59,  80,  82]],
#
#          [[134, 171, 209],
#           [134, 169, 212],
#           [135, 170, 213],
#           ...,
#           [ 45,  71,  73],
#           [ 51,  74,  76],
#           [ 47,  70,  71]],
#
#          [[133, 172, 207],
#           [131, 169, 209],
#           [133, 168, 211],
#           ...,
#           [ 58,  86,  87],
#           [ 61,  85,  87],
#           [ 59,  84,  86]]], dtype=uint8),
#   0],
#  [array([[[109, 124, 156],
#           [109, 124, 156],
#           [109, 124, 156],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          [[109, 124, 156],
#           [109, 124, 156],
#           [109, 124, 156],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          [[109, 124, 156],
#           [109, 124, 156],
#           [108, 123, 155],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          ...,
#
#          [[134, 169, 213],
#           [140, 175, 219],
#           [128, 162, 205],
#           ...,
#           [ 42,  67,  69],
#           [ 47,  70,  72],
#           [ 48,  71,  73]],
#
#          [[133, 168, 212],
#           [137, 172, 216],
#           [132, 166, 209],
#           ...,
#           [ 59,  84,  86],
#           [ 62,  85,  87],
#           [ 58,  81,  83]],
#
#          [[134, 169, 213],
#           [135, 170, 214],
#           [135, 169, 211],
#           ...,
#           [ 39,  63,  65],
#           [ 42,  65,  67],
#           [ 41,  63,  65]]], dtype=uint8),
#   0],
#  [array([[[111, 126, 158],
#           [111, 126, 158],
#           [112, 127, 159],
#           ...,
#           [129, 158, 189],
#           [129, 158, 189],
#           [129, 158, 189]],
#
#          [[111, 126, 158],
#           [111, 126, 158],
#           [112, 127, 159],
#           ...,
#           [129, 158, 189],
#           [129, 158, 189],
#           [129, 158, 189]],
#
#          [[109, 124, 156],
#           [111, 126, 158],
#           [111, 126, 158],
#           ...,
#           [129, 158, 189],
#           [129, 158, 189],
#           [129, 158, 189]],
#
#          ...,
#
#          [[136, 169, 214],
#           [138, 171, 216],
#           [138, 171, 216],
#           ...,
#           [ 58,  79,  81],
#           [ 54,  77,  79],
#           [ 55,  78,  80]],
#
#          [[135, 170, 214],
#           [135, 170, 214],
#           [134, 167, 212],
#           ...,
#           [ 64,  85,  87],
#           [ 59,  82,  84],
#           [ 56,  79,  82]],
#
#          [[134, 170, 214],
#           [134, 170, 214],
#           [136, 169, 213],
#           ...,
#           [ 53,  74,  76],
#           [ 54,  77,  79],
#           [ 54,  77,  79]]], dtype=uint8),
#   0],
#  [array([[[114, 127, 159],
#           [114, 127, 159],
#           [114, 129, 161],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          [[114, 127, 159],
#           [114, 127, 159],
#           [114, 129, 161],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          [[113, 126, 158],
#           [114, 127, 159],
#           [112, 127, 159],
#           ...,
#           [130, 159, 190],
#           [130, 159, 190],
#           [130, 159, 190]],
#
#          ...,
#
#          [[133, 168, 211],
#           [137, 172, 215],
#           [138, 172, 215],
#           ...,
#           [ 60,  85,  87],
#           [ 56,  81,  83],
#           [ 54,  79,  81]],
#
#          [[133, 168, 211],
#           [136, 171, 214],
#           [136, 170, 213],
#           ...,
#           [ 48,  73,  75],
#           [ 48,  73,  75],
#           [ 46,  71,  73]],
#
#          [[133, 168, 211],
#           [134, 169, 212],
#           [134, 168, 211],
#           ...,
#           [ 63,  88,  90],
#           [ 59,  84,  86],
#           [ 58,  83,  85]]], dtype=uint8),
#   0],
#  [array([[[118, 133, 165],
#           [118, 133, 165],
#           [119, 134, 166],
#           ...,
#           [132, 160, 190],
#           [131, 160, 191],
#           [131, 160, 191]],
#
#          [[118, 133, 165],
#           [118, 133, 165],
#           [119, 134, 166],
#           ...,
#           [132, 160, 190],
#           [131, 160, 191],
#           [131, 160, 191]],
#
#          [[118, 133, 165],
#           [118, 133, 165],
#           [118, 133, 165],
#           ...,
#           [132, 160, 190],
#           [132, 161, 192],
#           [132, 161, 192]],
#
#          ...,
#
#          [[136, 171, 215],
#           [133, 168, 213],
#           [135, 170, 214],
#           ...,
#           [ 68,  91,  93],
#           [ 60,  84,  88],
#           [ 57,  84,  88]],
#
#          [[133, 170, 214],
#           [130, 167, 211],
#           [133, 168, 212],
#           ...,
#           [ 47,  70,  72],
#           [ 46,  70,  74],
#           [ 42,  69,  73]],
#
#          [[131, 169, 213],
#           [127, 166, 210],
#           [131, 166, 210],
#           ...,
#           [ 77, 100, 102],
#           [ 63,  87,  91],
#           [ 60,  87,  91]]], dtype=uint8),
#   0],
#  [array([[[123, 138, 170],
#           [123, 138, 170],
#           [121, 138, 171],
#           ...,
#           [135, 162, 196],
#           [133, 160, 194],
#           [133, 160, 194]],
#
#          [[123, 138, 170],
#           [123, 138, 170],
#           [121, 138, 171],
#           ...,
#           [135, 162, 196],
#           [133, 160, 194],
#           [133, 160, 194]],
#
#          [[123, 138, 170],
#           [124, 139, 171],
#           [121, 138, 171],
#           ...,
#           [135, 162, 196],
#           [133, 160, 194],
#           [133, 160, 194]],
#
#          ...,
#
#          [[135, 170, 213],
#           [135, 170, 213],
#           [138, 170, 213],
#           ...,
#           [ 40,  68,  69],
#           [ 42,  73,  72],
#           [ 48,  78,  77]],
#
#          [[135, 170, 213],
#           [135, 170, 213],
#           [136, 170, 213],
#           ...,
#           [ 68,  96,  97],
#           [ 63,  94,  93],
#           [ 63,  94,  93]],
#
#          [[136, 171, 214],
#           [135, 169, 213],
#           [133, 168, 211],
#           ...,
#           [ 42,  70,  71],
#           [ 45,  75,  74],
#           [ 45,  76,  75]]], dtype=uint8),
#   0],
#  [array([[[118, 132, 168],
#           [118, 132, 168],
#           [121, 135, 171],
#           ...,
#           [131, 160, 191],
#           [131, 160, 191],
#           [131, 160, 191]],
#
#          [[118, 132, 168],
#           [118, 132, 168],
#           [119, 133, 169],
#           ...,
#           [133, 162, 193],
#           [131, 160, 191],
#           [131, 160, 191]],
#
#          [[116, 130, 166],
#           [118, 132, 168],
#           [118, 132, 168],
#           ...,
#           [131, 160, 191],
#           [131, 160, 191],
#           [131, 160, 191]],
#
#          ...,
#
#          [[133, 168, 212],
#           [134, 169, 213],
#           [135, 170, 213],
#           ...,
#           [ 52,  77,  79],
#           [ 51,  76,  78],
#           [ 54,  79,  81]],
#
#          [[135, 170, 214],
#           [134, 169, 213],
#           [130, 168, 210],
#           ...,
#           [ 57,  82,  84],
#           [ 59,  84,  86],
#           [ 57,  82,  84]],
#
#          [[136, 171, 215],
#           [137, 172, 216],
#           [129, 167, 209],
#           ...,
#           [ 47,  72,  74],
#           [ 37,  62,  64],
#           [ 46,  71,  73]]], dtype=uint8),
#   0],
#  [array([[[122, 136, 172],
#           [122, 136, 172],
#           [123, 137, 173],
#           ...,
#           [132, 160, 194],
#           [132, 161, 192],
#           [132, 161, 192]],
#
#          [[122, 136, 172],
#           [122, 136, 172],
#           [123, 137, 173],
#           ...,
#           [132, 160, 194],
#           [132, 161, 192],
#           [132, 161, 192]],
#
#          [[121, 135, 171],
#           [122, 136, 172],
#           [123, 137, 173],
#           ...,
#           [132, 160, 194],
#           [132, 161, 192],
#           [132, 161, 192]],
#
#          ...,
#
#          [[136, 172, 212],
#           [135, 171, 211],
#           [136, 167, 212],
#           ...,
#           [ 70,  93,  95],
#           [ 71,  92,  94],
#           [ 70,  91,  93]],
#
#          [[138, 174, 214],
#           [135, 171, 211],
#           [133, 166, 211],
#           ...,
#           [ 44,  67,  69],
#           [ 45,  68,  70],
#           [ 47,  70,  72]],
#
#          [[138, 174, 214],
#           [133, 169, 209],
#           [131, 166, 209],
#           ...,
#           [ 73,  96,  98],
#           [ 67,  91,  93],
#           [ 58,  82,  84]]], dtype=uint8),
#   0],
#  [array([[[109, 124, 156],
#           [109, 124, 156],
#           [111, 126, 158],
#           ...,
#           [129, 158, 189],
#           [129, 158, 189],
#           [129, 158, 189]],
#
#          [[109, 124, 156],
#           [109, 124, 156],
#           [111, 126, 158],
#           ...,
#           [129, 158, 189],
#           [129, 158, 189],
#           [129, 158, 189]],
#
#          [[110, 125, 157],
#           [109, 124, 156],
#           [111, 126, 158],
#           ...,
#           [130, 159, 190],
#           [129, 158, 189],
#           [129, 158, 189]],
#
#          ...,
#
#          [[132, 165, 208],
#           [134, 168, 211],
#           [141, 175, 218],
#           ...,
#           [ 68,  89,  91],
#           [ 70,  90,  91],
#           [ 73,  91,  92]],
#
#          [[127, 161, 204],
#           [136, 170, 213],
#           [140, 174, 217],
#           ...,
#           [ 45,  65,  70],
#           [ 47,  67,  69],
#           [ 51,  68,  70]],
#
#          [[131, 166, 209],
#           [132, 166, 209],
#           [135, 169, 212],
#           ...,
#           [ 78,  98, 103],
#           [ 70,  90,  94],
#           [ 67,  84,  89]]], dtype=uint8),
#   0],
#  [array([[[109, 124, 156],
#           [109, 124, 156],
#           [111, 126, 158],
#           ...,
#           [129, 158, 189],
#           [129, 158, 189],
#           [129, 158, 189]],
#
#          [[109, 124, 156],
#           [109, 124, 156],
#           [111, 126, 158],
#           ...,
#           [129, 158, 189],
#           [129, 158, 189],
#           [129, 158, 189]],
#
#          [[108, 123, 155],
#           [109, 124, 156],
#           [109, 124, 156],
#           ...,
#           [129, 158, 189],
#           [129, 158, 189],
#           [129, 158, 189]],
#
#          ...,
#
#          [[131, 165, 208],
#           [134, 168, 211],
#           [135, 171, 211],
#           ...,
#           [ 70,  93,  95],
#           [ 61,  88,  92],
#           [ 59,  86,  90]],
#
#          [[129, 163, 206],
#           [134, 168, 211],
#           [132, 168, 208],
#           ...,
#           [ 41,  67,  69],
#           [ 38,  67,  69],
#           [ 38,  67,  69]],
#
#          [[128, 162, 205],
#           [132, 166, 209],
#           [128, 164, 204],
#           ...,
#           [ 67,  98,  99],
#           [ 63,  94,  93],
#           [ 56,  87,  87]]], dtype=uint8),
#   0],
#  [array([[[121, 135, 171],
#           [122, 136, 172],
#           [122, 136, 172],
#           ...,
#           [134, 163, 194],
#           [132, 161, 192],
#           [132, 161, 192]],
#
#          [[121, 135, 171],
#           [122, 136, 172],
#           [122, 136, 172],
#           ...,
#           [134, 163, 194],
#           [132, 161, 192],
#           [132, 161, 192]],
#
#          [[120, 134, 170],
#           [121, 135, 171],
#           [120, 134, 170],
#           ...,
#           [134, 163, 194],
#           [134, 163, 194],
#           [134, 163, 194]],
#
#          ...,
#
#          [[137, 171, 214],
#           [136, 170, 213],
#           [136, 170, 213],
#           ...,
#           [ 51,  81,  82],
#           [ 47,  78,  79],
#           [ 48,  79,  81]],
#
#          [[140, 174, 217],
#           [135, 169, 213],
#           [133, 167, 210],
#           ...,
#           [ 54,  84,  85],
#           [ 56,  87,  88],
#           [ 55,  86,  87]],
#
#          [[137, 171, 214],
#           [134, 168, 211],
#           [132, 166, 209],
#           ...,
#           [ 48,  78,  79],
#           [ 50,  81,  82],
#           [ 52,  83,  84]]], dtype=uint8),
#   0],
#  [array([[[123, 137, 173],
#           [123, 137, 173],
#           [123, 137, 173],
#           ...,
#           [132, 161, 192],
#           [132, 161, 192],
#           [132, 161, 192]],
#
#          [[123, 137, 173],
#           [123, 137, 173],
#           [123, 137, 173],
#           ...,
#           [132, 161, 192],
#           [132, 161, 192],
#           [132, 161, 192]],
#
#          [[123, 137, 173],
#           [122, 136, 172],
#           [122, 136, 172],
#           ...,
#           [132, 161, 192],
#           [132, 161, 192],
#           [132, 161, 192]],
#
#          ...,
#
#          [[140, 173, 215],
#           [136, 168, 211],
#           [136, 170, 213],
#           ...,
#           [ 58,  79,  81],
#           [ 55,  80,  83],
#           [ 54,  79,  81]],
#
#          [[138, 172, 215],
#           [137, 171, 214],
#           [133, 167, 210],
#           ...,
#           [ 60,  81,  83],
#           [ 52,  77,  79],
#           [ 52,  78,  79]],
#
#          [[137, 172, 215],
#           [136, 171, 214],
#           [137, 171, 213],
#           ...,
#           [ 65,  86,  88],
#           [ 58,  83,  85],
#           [ 54,  79,  81]]], dtype=uint8),
#   0],
#  [array([[[119, 132, 169],
#           [119, 132, 169],
#           [118, 131, 169],
#           ...,
#           [129, 160, 193],
#           [129, 160, 193],
#           [129, 160, 193]],
#
#          [[119, 133, 168],
#           [119, 133, 169],
#           [118, 132, 168],
#           ...,
#           [129, 160, 193],
#           [129, 160, 193],
#           [129, 160, 193]],
#
#          [[118, 133, 166],
#           [118, 133, 166],
#           [118, 133, 166],
#           ...,
#           [129, 160, 193],
#           [129, 160, 193],
#           [129, 160, 193]],
#
#          ...,
#
#          [[137, 172, 216],
#           [132, 167, 211],
#           [138, 167, 211],
#           ...,
#           [ 52,  76,  78],
#           [ 56,  77,  79],
#           [ 56,  77,  79]],
#
#          [[137, 172, 216],
#           [133, 168, 213],
#           [135, 167, 210],
#           ...,
#           [ 60,  85,  87],
#           [ 59,  82,  84],
#           [ 58,  81,  83]],
#
#          [[134, 169, 213],
#           [133, 168, 212],
#           [137, 168, 211],
#           ...,
#           [ 54,  79,  81],
#           [ 57,  81,  84],
#           [ 53,  77,  79]]], dtype=uint8),
#   0],
#  [array([[[123, 137, 173],
#           [123, 137, 173],
#           [124, 138, 174],
#           ...,
#           [134, 163, 194],
#           [134, 163, 194],
#           [134, 163, 194]],
#
#          [[123, 137, 173],
#           [123, 137, 173],
#           [124, 138, 174],
#           ...,
#           [134, 163, 194],
#           [134, 163, 194],
#           [134, 163, 194]],
#
#          [[122, 136, 172],
#           [123, 137, 173],
#           [124, 138, 174],
#           ...,
#           [135, 164, 195],
#           [134, 163, 194],
#           [134, 163, 194]],
#
#          ...,
#
#          [[136, 171, 215],
#           [132, 167, 211],
#           [134, 166, 209],
#           ...,
#           [ 64,  83,  89],
#           [ 61,  82,  84],
#           [ 58,  79,  81]],
#
#          [[136, 171, 215],
#           [132, 167, 211],
#           [135, 167, 210],
#           ...,
#           [ 65,  83,  88],
#           [ 60,  81,  82],
#           [ 60,  81,  83]],
#
#          [[135, 170, 214],
#           [133, 168, 212],
#           [138, 169, 213],
#           ...,
#           [ 61,  80,  85],
#           [ 57,  78,  80],
#           [ 56,  77,  79]]], dtype=uint8),
#   0],
#  [array([[[121, 136, 168],
#           [121, 136, 168],
#           [121, 138, 171],
#           ...,
#           [136, 165, 196],
#           [137, 166, 197],
#           [136, 165, 196]],
#
#          [[121, 136, 168],
#           [121, 136, 168],
#           [121, 138, 171],
#           ...,
#           [136, 165, 196],
#           [137, 166, 197],
#           [136, 165, 196]],
#
#          [[120, 135, 167],
#           [120, 135, 167],
#           [121, 138, 171],
#           ...,
#           [137, 166, 197],
#           [137, 166, 197],
#           [136, 165, 196]],
#
#          ...,
#
#          [[136, 168, 211],
#           [135, 167, 210],
#           [130, 164, 207],
#           ...,
#           [ 58,  86,  87],
#           [ 67,  92,  94],
#           [ 61,  86,  88]],
#
#          [[138, 167, 211],
#           [137, 166, 210],
#           [133, 167, 210],
#           ...,
#           [ 45,  73,  74],
#           [ 49,  74,  76],
#           [ 53,  78,  80]],
#
#          [[137, 165, 209],
#           [141, 168, 212],
#           [132, 165, 208],
#           ...,
#           [ 71,  99, 100],
#           [ 65,  90,  92],
#           [ 60,  85,  87]]], dtype=uint8),
#   0],
#  [array([[[111, 126, 158],
#           [112, 127, 159],
#           [113, 129, 158],
#           ...,
#           [141, 174, 207],
#           [141, 174, 207],
#           [140, 173, 206]],
#
#          [[111, 126, 158],
#           [112, 127, 159],
#           [113, 129, 158],
#           ...,
#           [141, 174, 207],
#           [141, 174, 207],
#           [140, 173, 206]],
#
#          [[111, 126, 158],
#           [112, 127, 159],
#           [111, 127, 156],
#           ...,
#           [141, 174, 207],
#           [141, 174, 207],
#           [140, 173, 206]],
#
#          ...,
#
#          [[138, 172, 215],
#           [139, 173, 216],
#           [139, 168, 212],
#           ...,
#           [ 63,  94,  93],
#           [ 65,  94,  94],
#           [ 72,  91,  96]],
#
#          [[139, 173, 216],
#           [136, 170, 213],
#           [139, 168, 212],
#           ...,
#           [ 47,  77,  76],
#           [ 47,  77,  77],
#           [ 54,  73,  78]],
#
#          [[137, 171, 214],
#           [132, 166, 209],
#           [136, 165, 209],
#           ...,
#           [ 69,  99,  98],
#           [ 63,  92,  92],
#           [ 77,  96, 101]]], dtype=uint8),
#   0],
#  [array([[[111, 126, 158],
#           [111, 126, 158],
#           [112, 127, 159],
#           ...,
#           [140, 173, 206],
#           [140, 173, 206],
#           [140, 173, 206]],
#
#          [[111, 126, 158],
#           [111, 126, 158],
#           [112, 127, 159],
#           ...,
#           [140, 173, 206],
#           [140, 173, 206],
#           [140, 173, 206]],
#
#          [[110, 125, 157],
#           [110, 125, 157],
#           [111, 126, 158],
#           ...,
#           [140, 173, 206],
#           [140, 173, 206],
#           [140, 173, 206]],
#
#          ...,
#
#          [[141, 175, 218],
#           [139, 173, 216],
#           [140, 174, 217],
#           ...,
#           [ 69,  97,  98],
#           [ 63,  93,  94],
#           [ 58,  88,  89]],
#
#          [[141, 175, 218],
#           [139, 173, 216],
#           [140, 172, 215],
#           ...,
#           [ 47,  75,  76],
#           [ 42,  72,  73],
#           [ 37,  66,  67]],
#
#          [[142, 176, 219],
#           [142, 175, 218],
#           [137, 169, 212],
#           ...,
#           [ 75, 103, 104],
#           [ 59,  90,  90],
#           [ 63,  93,  94]]], dtype=uint8),
#   0],
#  [array([[[111, 126, 158],
#           [111, 126, 158],
#           [111, 126, 158],
#           ...,
#           [142, 173, 206],
#           [141, 172, 205],
#           [141, 172, 205]],
#
#          [[109, 124, 156],
#           [111, 126, 158],
#           [111, 126, 158],
#           ...,
#           [142, 173, 206],
#           [141, 172, 205],
#           [141, 172, 205]],
#
#          [[109, 124, 156],
#           [111, 126, 158],
#           [111, 126, 158],
#           ...,
#           [142, 173, 206],
#           [140, 171, 204],
#           [141, 172, 205]],
#
#          ...,
#
#          [[145, 177, 220],
#           [140, 172, 215],
#           [137, 171, 214],
#           ...,
#           [ 72, 100, 100],
#           [ 68,  93,  95],
#           [ 63,  88,  90]],
#
#          [[147, 176, 220],
#           [144, 173, 217],
#           [139, 171, 214],
#           ...,
#           [ 44,  73,  73],
#           [ 43,  71,  72],
#           [ 45,  73,  74]],
#
#          [[146, 174, 218],
#           [146, 173, 217],
#           [138, 167, 211],
#           ...,
#           [ 69,  97,  98],
#           [ 64,  93,  94],
#           [ 64,  94,  95]]], dtype=uint8),
#   0],
#  [array([[[111, 126, 158],
#           [111, 126, 158],
#           [111, 126, 158],
#           ...,
#           [142, 173, 206],
#           [140, 173, 206],
#           [140, 173, 206]],
#
#          [[109, 124, 156],
#           [111, 126, 158],
#           [111, 126, 158],
#           ...,
#           [142, 173, 206],
#           [140, 173, 206],
#           [140, 173, 206]],
#
#          [[109, 124, 156],
#           [111, 126, 158],
#           [111, 126, 158],
#           ...,
#           [142, 173, 206],
#           [140, 173, 206],
#           [140, 173, 206]],
#
#          ...,
#
#          [[142, 176, 219],
#           [140, 174, 217],
#           [142, 174, 217],
#           ...,
#           [ 70,  98,  98],
#           [ 68,  98,  99],
#           [ 64,  95,  95]],
#
#          [[143, 175, 218],
#           [143, 175, 218],
#           [143, 172, 216],
#           ...,
#           [ 45,  73,  74],
#           [ 46,  75,  76],
#           [ 44,  75,  76]],
#
#          [[143, 173, 217],
#           [145, 175, 219],
#           [144, 173, 217],
#           ...,
#           [ 74, 101, 104],
#           [ 68,  97,  98],
#           [ 61,  92,  93]]], dtype=uint8),
#   0],
#  [array([[[110, 123, 155],
#           [111, 124, 156],
#           [111, 124, 156],
#           ...,
#           [142, 173, 206],
#           [141, 172, 205],
#           [141, 172, 205]],
#
#          [[110, 123, 155],
#           [111, 124, 156],
#           [111, 124, 156],
#           ...,
#           [142, 173, 206],
#           [141, 172, 205],
#           [141, 172, 205]],
#
#          [[110, 123, 155],
#           [110, 123, 155],
#           [110, 123, 155],
#           ...,
#           [142, 173, 206],
#           [141, 172, 205],
#           [141, 172, 205]],
#
#          ...,
#
#          [[142, 176, 219],
#           [140, 174, 217],
#           [135, 169, 212],
#           ...,
#           [ 69,  97,  98],
#           [ 69,  94,  96],
#           [ 69,  94,  96]],
#
#          [[142, 174, 217],
#           [141, 173, 216],
#           [136, 168, 211],
#           ...,
#           [ 48,  73,  75],
#           [ 53,  78,  79],
#           [ 55,  80,  82]],
#
#          [[141, 171, 215],
#           [141, 171, 215],
#           [139, 169, 213],
#           ...,
#           [ 78, 102, 104],
#           [ 70,  95,  97],
#           [ 64,  89,  91]]], dtype=uint8),
#   0],
#  [array([[[105, 121, 150],
#           [106, 122, 151],
#           [106, 121, 153],
#           ...,
#           [142, 173, 206],
#           [141, 172, 205],
#           [141, 172, 205]],
#
#          [[105, 121, 150],
#           [106, 122, 151],
#           [106, 121, 153],
#           ...,
#           [142, 173, 206],
#           [141, 172, 205],
#           [141, 172, 205]],
#
#          [[103, 119, 148],
#           [104, 120, 149],
#           [104, 119, 151],
#           ...,
#           [142, 173, 206],
#           [142, 173, 206],
#           [142, 173, 206]],
#
#          ...,
#
#          [[133, 171, 215],
#           [133, 170, 214],
#           [130, 165, 208],
#           ...,
#           [ 65,  88,  90],
#           [ 61,  91,  92],
#           [ 61,  91,  92]],
#
#          [[139, 170, 215],
#           [139, 169, 214],
#           [128, 162, 205],
#           ...,
#           [ 56,  80,  82],
#           [ 48,  78,  79],
#           [ 49,  79,  80]],
#
#          [[138, 167, 212],
#           [140, 169, 214],
#           [138, 170, 213],
#           ...,
#           [ 57,  82,  84],
#           [ 60,  90,  91],
#           [ 54,  84,  85]]], dtype=uint8),
#   0],
#  [array([[[111, 126, 158],
#           [111, 126, 158],
#           [115, 130, 162],
#           ...,
#           [140, 173, 206],
#           [142, 173, 206],
#           [142, 173, 206]],
#
#          [[111, 126, 158],
#           [111, 126, 158],
#           [113, 128, 160],
#           ...,
#           [140, 173, 206],
#           [142, 173, 206],
#           [142, 173, 206]],
#
#          [[109, 124, 156],
#           [109, 124, 156],
#           [112, 127, 159],
#           ...,
#           [140, 173, 206],
#           [142, 173, 206],
#           [142, 173, 206]],
#
#          ...,
#
#          [[142, 176, 219],
#           [139, 173, 216],
#           [139, 171, 212],
#           ...,
#           [ 60,  85,  87],
#           [ 62,  87,  89],
#           [ 59,  84,  86]],
#
#          [[148, 175, 219],
#           [147, 173, 217],
#           [148, 173, 215],
#           ...,
#           [ 69,  92,  94],
#           [ 59,  84,  86],
#           [ 58,  83,  85]],
#
#          [[148, 173, 217],
#           [150, 175, 219],
#           [149, 174, 216],
#           ...,
#           [ 69,  94,  96],
#           [ 62,  87,  89],
#           [ 60,  85,  87]]], dtype=uint8),
#   0],
#  [array([[[111, 126, 158],
#           [112, 127, 159],
#           [113, 128, 160],
#           ...,
#           [142, 173, 206],
#           [143, 174, 207],
#           [143, 174, 207]],
#
#          [[111, 126, 158],
#           [112, 127, 159],
#           [113, 128, 160],
#           ...,
#           [142, 173, 206],
#           [143, 174, 207],
#           [143, 174, 207]],
#
#          [[109, 124, 156],
#           [110, 125, 157],
#           [112, 127, 159],
#           ...,
#           [142, 173, 206],
#           [143, 174, 207],
#           [143, 174, 207]],
#
#          ...,
#
#          [[141, 179, 221],
#           [138, 176, 218],
#           [137, 172, 216],
#           ...,
#           [ 46,  77,  78],
#           [ 49,  76,  78],
#           [ 47,  75,  76]],
#
#          [[142, 176, 219],
#           [142, 176, 219],
#           [141, 174, 219],
#           ...,
#           [ 74, 105, 106],
#           [ 79, 107, 108],
# ...
#           ...,
#           [ 80, 104, 126],
#           [ 78, 102, 124],
#           [ 76, 100, 122]],
#
#          [[ 83, 104, 131],
#           [113, 134, 161],
#           [113, 134, 161],
#           ...,
#           [ 79, 103, 125],
#           [ 77, 101, 123],
#           [ 75,  99, 121]]], dtype=uint8),
#   1],
#  [array([[[147, 172, 198],
#           [147, 172, 198],
#           [148, 173, 199],
#           ...,
#           [147, 177, 196],
#           [148, 178, 197],
#           [151, 181, 200]],
#
#          [[147, 172, 198],
#           [147, 172, 198],
#           [148, 173, 199],
#           ...,
#           [147, 177, 196],
#           [148, 178, 197],
#           [151, 181, 200]],
#
#          [[147, 172, 198],
#           [147, 172, 198],
#           [148, 173, 199],
#           ...,
#           [147, 177, 196],
#           [148, 178, 197],
#           [151, 181, 200]],
#
#          ...,
#
#          [[116, 139, 165],
#           [119, 142, 168],
#           [118, 141, 167],
#           ...,
#           [ 73,  97, 117],
#           [ 73,  94, 115],
#           [ 73,  92, 113]],
#
#          [[119, 142, 168],
#           [117, 140, 166],
#           [117, 140, 166],
#           ...,
#           [ 73,  96, 117],
#           [ 72,  93, 114],
#           [ 73,  91, 112]],
#
#          [[ 86, 109, 135],
#           [117, 140, 166],
#           [116, 139, 165],
#           ...,
#           [ 72,  96, 116],
#           [ 71,  92, 113],
#           [ 72,  91, 111]]], dtype=uint8),
#   1],
#  [array([[[151, 174, 200],
#           [151, 174, 200],
#           [151, 174, 200],
#           ...,
#           [143, 173, 192],
#           [147, 177, 196],
#           [149, 179, 198]],
#
#          [[151, 174, 200],
#           [151, 174, 200],
#           [151, 174, 200],
#           ...,
#           [143, 173, 192],
#           [147, 177, 196],
#           [149, 179, 198]],
#
#          [[151, 174, 200],
#           [151, 174, 200],
#           [152, 174, 200],
#           ...,
#           [143, 173, 192],
#           [147, 177, 196],
#           [149, 179, 198]],
#
#          ...,
#
#          [[107, 126, 159],
#           [116, 135, 166],
#           [111, 132, 158],
#           ...,
#           [ 71,  95, 113],
#           [ 69,  93, 111],
#           [ 67,  91, 109]],
#
#          [[ 50,  67, 106],
#           [112, 131, 164],
#           [109, 130, 157],
#           ...,
#           [ 72,  96, 114],
#           [ 69,  93, 111],
#           [ 67,  91, 109]],
#
#          [[ 42,  58,  98],
#           [ 64,  83, 116],
#           [111, 132, 160],
#           ...,
#           [ 70,  94, 112],
#           [ 69,  93, 111],
#           [ 67,  91, 109]]], dtype=uint8),
#   1],
#  [array([[[148, 173, 199],
#           [148, 173, 199],
#           [149, 174, 200],
#           ...,
#           [147, 178, 199],
#           [148, 179, 200],
#           [152, 183, 204]],
#
#          [[148, 173, 199],
#           [148, 173, 199],
#           [149, 174, 200],
#           ...,
#           [146, 177, 198],
#           [148, 179, 200],
#           [152, 183, 204]],
#
#          [[148, 173, 199],
#           [148, 173, 199],
#           [149, 174, 200],
#           ...,
#           [145, 176, 197],
#           [148, 179, 200],
#           [152, 183, 204]],
#
#          ...,
#
#          [[ 48,  76, 110],
#           [100, 127, 160],
#           [109, 133, 163],
#           ...,
#           [ 73,  97, 115],
#           [ 73,  97, 115],
#           [ 69,  93, 111]],
#
#          [[ 36,  65, 101],
#           [ 47,  74, 109],
#           [110, 135, 168],
#           ...,
#           [ 73,  97, 115],
#           [ 72,  96, 114],
#           [ 69,  93, 111]],
#
#          [[ 26,  55,  93],
#           [ 41,  69, 104],
#           [ 51,  78, 112],
#           ...,
#           [ 71,  95, 113],
#           [ 71,  95, 113],
#           [ 68,  92, 110]]], dtype=uint8),
#   1],
#  [array([[[151, 176, 202],
#           [152, 177, 203],
#           [150, 175, 201],
#           ...,
#           [147, 178, 199],
#           [149, 180, 201],
#           [151, 182, 203]],
#
#          [[151, 175, 202],
#           [152, 177, 203],
#           [150, 175, 201],
#           ...,
#           [147, 178, 199],
#           [149, 180, 201],
#           [151, 182, 203]],
#
#          [[151, 176, 202],
#           [152, 177, 203],
#           [150, 175, 201],
#           ...,
#           [147, 178, 199],
#           [149, 180, 201],
#           [151, 182, 203]],
#
#          ...,
#
#          [[ 46,  70, 106],
#           [ 79, 103, 139],
#           [115, 141, 173],
#           ...,
#           [ 74,  98, 116],
#           [ 72,  96, 114],
#           [ 70,  94, 112]],
#
#          [[ 39,  61, 101],
#           [ 48,  71, 109],
#           [ 83, 108, 142],
#           ...,
#           [ 73,  98, 116],
#           [ 71,  95, 113],
#           [ 69,  93, 111]],
#
#          [[ 24,  46,  87],
#           [ 42,  65, 103],
#           [ 50,  74, 110],
#           ...,
#           [ 73,  97, 115],
#           [ 70,  94, 112],
#           [ 68,  92, 110]]], dtype=uint8),
#   1],
#  [array([[[114, 143, 147],
#           [176, 207, 210],
#           [192, 223, 225],
#           ...,
#           [105, 118, 123],
#           [113, 126, 128],
#           [105, 123, 130]],
#
#          [[127, 156, 160],
#           [124, 155, 158],
#           [123, 154, 157],
#           ...,
#           [109, 121, 122],
#           [108, 122, 120],
#           [109, 122, 124]],
#
#          [[130, 160, 165],
#           [131, 162, 165],
#           [135, 166, 169],
#           ...,
#           [108, 120, 124],
#           [109, 123, 122],
#           [107, 121, 120]],
#
#          ...,
#
#          [[ 30,  54,  74],
#           [ 29,  53,  77],
#           [ 30,  55,  74],
#           ...,
#           [  7,  53, 111],
#           [  7,  53, 111],
#           [  9,  55, 113]],
#
#          [[ 28,  53,  73],
#           [ 29,  53,  77],
#           [ 29,  54,  73],
#           ...,
#           [  7,  53, 111],
#           [  6,  53, 111],
#           [  9,  54, 112]],
#
#          [[ 29,  50,  72],
#           [ 30,  54,  74],
#           [ 29,  52,  77],
#           ...,
#           [  7,  53, 111],
#           [  6,  52, 110],
#           [  2,  48, 106]]], dtype=uint8),
#   1],
#  [array([[[145, 171, 195],
#           [147, 173, 197],
#           [147, 173, 197],
#           ...,
#           [146, 177, 198],
#           [145, 176, 197],
#           [147, 178, 199]],
#
#          [[145, 171, 195],
#           [147, 173, 197],
#           [148, 174, 198],
#           ...,
#           [143, 174, 195],
#           [145, 176, 197],
#           [147, 178, 199]],
#
#          [[145, 171, 195],
#           [147, 173, 197],
#           [149, 175, 199],
#           ...,
#           [144, 175, 196],
#           [145, 176, 197],
#           [147, 178, 199]],
#
#          ...,
#
#          [[ 44,  70, 106],
#           [ 92, 114, 151],
#           [118, 139, 171],
#           ...,
#           [ 79,  98, 119],
#           [ 78,  97, 118],
#           [ 74,  93, 114]],
#
#          [[ 35,  62, 101],
#           [ 51,  74, 112],
#           [ 95, 114, 150],
#           ...,
#           [ 77,  96, 117],
#           [ 77,  96, 117],
#           [ 74,  93, 114]],
#
#          [[ 27,  56,  95],
#           [ 46,  69, 107],
#           [ 60,  79, 116],
#           ...,
#           [ 76,  95, 116],
#           [ 76,  95, 116],
#           [ 73,  92, 113]]], dtype=uint8),
#   1],
#  [array([[[150, 175, 201],
#           [152, 177, 203],
#           [152, 177, 203],
#           ...,
#           [146, 177, 198],
#           [146, 177, 198],
#           [148, 179, 200]],
#
#          [[150, 175, 201],
#           [152, 177, 203],
#           [152, 177, 203],
#           ...,
#           [146, 177, 198],
#           [146, 177, 198],
#           [148, 179, 200]],
#
#          [[150, 175, 201],
#           [152, 177, 203],
#           [152, 177, 203],
#           ...,
#           [146, 177, 198],
#           [146, 177, 198],
#           [148, 179, 200]],
#
#          ...,
#
#          [[ 48,  68, 103],
#           [ 89, 110, 142],
#           [122, 143, 173],
#           ...,
#           [ 73,  98, 114],
#           [ 71,  96, 112],
#           [ 69,  94, 110]],
#
#          [[ 46,  65, 102],
#           [ 58,  78, 112],
#           [ 97, 118, 149],
#           ...,
#           [ 72,  97, 113],
#           [ 70,  95, 111],
#           [ 68,  93, 109]],
#
#          [[ 33,  52,  89],
#           [ 46,  66, 101],
#           [ 62,  82, 115],
#           ...,
#           [ 72,  96, 112],
#           [ 69,  94, 110],
#           [ 67,  92, 108]]], dtype=uint8),
#   1],
#  [array([[[149, 174, 200],
#           [151, 176, 202],
#           [151, 176, 202],
#           ...,
#           [145, 176, 197],
#           [146, 177, 198],
#           [148, 179, 200]],
#
#          [[149, 174, 200],
#           [151, 176, 202],
#           [151, 176, 202],
#           ...,
#           [145, 176, 197],
#           [146, 177, 198],
#           [148, 179, 200]],
#
#          [[149, 174, 200],
#           [151, 176, 202],
#           [151, 176, 202],
#           ...,
#           [145, 176, 197],
#           [146, 177, 198],
#           [148, 179, 200]],
#
#          ...,
#
#          [[ 37,  56,  93],
#           [ 50,  69, 106],
#           [ 65,  84, 120],
#           ...,
#           [ 74,  99, 115],
#           [ 73,  98, 114],
#           [ 73,  98, 114]],
#
#          [[ 28,  46,  83],
#           [ 44,  62,  99],
#           [ 58,  75, 114],
#           ...,
#           [ 73,  98, 114],
#           [ 74,  99, 115],
#           [ 70,  95, 111]],
#
#          [[ 25,  41,  78],
#           [ 36,  52,  89],
#           [ 46,  61, 100],
#           ...,
#           [ 72,  97, 113],
#           [ 71,  96, 112],
#           [ 71,  96, 112]]], dtype=uint8),
#   1],
#  [array([[[148, 173, 199],
#           [148, 173, 199],
#           [149, 174, 200],
#           ...,
#           [147, 178, 199],
#           [149, 180, 201],
#           [149, 180, 201]],
#
#          [[148, 173, 199],
#           [148, 173, 199],
#           [150, 174, 200],
#           ...,
#           [146, 177, 198],
#           [148, 179, 200],
#           [149, 180, 201]],
#
#          [[148, 173, 199],
#           [148, 173, 199],
#           [150, 175, 201],
#           ...,
#           [145, 175, 196],
#           [147, 178, 199],
#           [150, 181, 202]],
#
#          ...,
#
#          [[ 43,  62,  99],
#           [ 57,  76, 113],
#           [ 99, 120, 152],
#           ...,
#           [ 73,  98, 118],
#           [ 71,  96, 116],
#           [ 71,  96, 116]],
#
#          [[ 35,  53,  93],
#           [ 52,  71, 109],
#           [ 59,  79, 114],
#           ...,
#           [ 72,  97, 117],
#           [ 70,  95, 115],
#           [ 70,  94, 114]],
#
#          [[ 34,  52,  94],
#           [ 42,  61,  99],
#           [ 48,  67, 104],
#           ...,
#           [ 72,  96, 116],
#           [ 68,  93, 114],
#           [ 69,  94, 114]]], dtype=uint8),
#   1],
#  [array([[[149, 174, 200],
#           [149, 174, 200],
#           [148, 173, 199],
#           ...,
#           [142, 173, 194],
#           [144, 175, 196],
#           [146, 177, 198]],
#
#          [[149, 174, 200],
#           [149, 174, 200],
#           [148, 173, 199],
#           ...,
#           [142, 173, 194],
#           [144, 175, 196],
#           [146, 177, 198]],
#
#          [[149, 174, 200],
#           [149, 174, 200],
#           [148, 173, 199],
#           ...,
#           [142, 173, 194],
#           [144, 175, 196],
#           [146, 177, 198]],
#
#          ...,
#
#          [[ 27,  52,  90],
#           [ 53,  76, 114],
#           [ 76,  96, 131],
#           ...,
#           [ 74,  98, 116],
#           [ 72,  96, 114],
#           [ 72,  96, 114]],
#
#          [[ 18,  48,  88],
#           [ 41,  66, 106],
#           [ 53,  71, 109],
#           ...,
#           [ 73,  98, 116],
#           [ 74,  98, 116],
#           [ 69,  93, 111]],
#
#          [[ 17,  48,  89],
#           [ 33,  58,  98],
#           [ 47,  65, 103],
#           ...,
#           [ 73,  97, 115],
#           [ 73,  97, 115],
#           [ 68,  92, 110]]], dtype=uint8),
#   1],
#  [array([[[148, 173, 199],
#           [148, 173, 199],
#           [150, 175, 201],
#           ...,
#           [141, 172, 193],
#           [144, 175, 196],
#           [146, 177, 198]],
#
#          [[148, 173, 199],
#           [148, 173, 199],
#           [150, 175, 201],
#           ...,
#           [141, 172, 193],
#           [144, 175, 196],
#           [146, 177, 198]],
#
#          [[148, 173, 199],
#           [148, 173, 199],
#           [150, 175, 201],
#           ...,
#           [141, 172, 193],
#           [144, 175, 196],
#           [146, 177, 198]],
#
#          ...,
#
#          [[ 19,  41,  82],
#           [ 46,  66, 107],
#           [ 59,  75, 112],
#           ...,
#           [ 74,  98, 116],
#           [ 72,  96, 114],
#           [ 69,  93, 111]],
#
#          [[ 26,  42,  88],
#           [ 35,  52,  94],
#           [ 51,  71, 110],
#           ...,
#           [ 73,  97, 115],
#           [ 71,  95, 113],
#           [ 69,  93, 111]],
#
#          [[ 12,  25,  71],
#           [ 32,  48,  91],
#           [ 37,  58,  99],
#           ...,
#           [ 73,  96, 114],
#           [ 70,  94, 112],
#           [ 70,  94, 112]]], dtype=uint8),
#   1],
#  [array([[[148, 173, 199],
#           [148, 173, 199],
#           [149, 174, 200],
#           ...,
#           [140, 171, 192],
#           [140, 171, 192],
#           [143, 174, 195]],
#
#          [[148, 173, 199],
#           [148, 173, 199],
#           [149, 174, 200],
#           ...,
#           [140, 171, 192],
#           [140, 171, 192],
#           [143, 174, 195]],
#
#          [[148, 173, 199],
#           [148, 173, 199],
#           [149, 174, 200],
#           ...,
#           [140, 171, 192],
#           [140, 171, 192],
#           [143, 174, 195]],
#
#          ...,
#
#          [[ 35,  50,  94],
#           [ 41,  58, 100],
#           [ 57,  75, 115],
#           ...,
#           [ 75, 100, 120],
#           [ 73,  98, 118],
#           [ 69,  94, 114]],
#
#          [[ 28,  39,  83],
#           [ 38,  51,  96],
#           [ 49,  66, 111],
#           ...,
#           [ 74,  99, 119],
#           [ 72,  97, 117],
#           [ 69,  93, 114]],
#
#          [[ 17,  26,  70],
#           [ 36,  49,  95],
#           [ 38,  54, 101],
#           ...,
#           [ 73,  98, 118],
#           [ 71,  96, 116],
#           [ 68,  93, 113]]], dtype=uint8),
#   1],
#  [array([[[149, 174, 200],
#           [149, 174, 200],
#           [151, 176, 202],
#           ...,
#           [141, 172, 193],
#           [143, 174, 195],
#           [145, 176, 197]],
#
#          [[149, 174, 200],
#           [149, 174, 200],
#           [151, 176, 202],
#           ...,
#           [141, 172, 193],
#           [143, 174, 195],
#           [145, 176, 197]],
#
#          [[149, 174, 200],
#           [149, 174, 200],
#           [151, 176, 202],
#           ...,
#           [141, 172, 193],
#           [143, 174, 195],
#           [145, 176, 197]],
#
#          ...,
#
#          [[ 32,  49,  88],
#           [ 43,  60,  99],
#           [ 60,  76, 118],
#           ...,
#           [ 74, 101, 121],
#           [ 72,  99, 119],
#           [ 70,  98, 117]],
#
#          [[ 27,  46,  82],
#           [ 35,  53,  90],
#           [ 52,  68, 110],
#           ...,
#           [ 73, 100, 121],
#           [ 70,  97, 117],
#           [ 68,  95, 115]],
#
#          [[  8,  27,  60],
#           [ 25,  43,  80],
#           [ 37,  53,  95],
#           ...,
#           [ 70,  97, 117],
#           [ 71,  98, 118],
#           [ 69,  95, 115]]], dtype=uint8),
#   1],
#  [array([[[177, 207, 208],
#           [193, 224, 227],
#           [185, 217, 222],
#           ...,
#           [100, 116, 115],
#           [113, 124, 128],
#           [105, 123, 130]],
#
#          [[124, 154, 155],
#           [123, 153, 156],
#           [119, 148, 153],
#           ...,
#           [106, 119, 119],
#           [107, 119, 119],
#           [107, 121, 122]],
#
#          [[129, 159, 164],
#           [136, 166, 167],
#           [137, 167, 168],
#           ...,
#           [106, 120, 119],
#           [107, 121, 120],
#           [105, 119, 118]],
#
#          ...,
#
#          [[ 28,  52,  72],
#           [ 28,  50,  75],
#           [ 28,  50,  75],
#           ...,
#           [  6,  54, 112],
#           [ 10,  55, 116],
#           [ 10,  55, 116]],
#
#          [[ 28,  52,  72],
#           [ 29,  51,  76],
#           [ 28,  50,  75],
#           ...,
#           [  6,  54, 112],
#           [  9,  54, 115],
#           [ 10,  55, 116]],
#
#          [[ 27,  51,  71],
#           [ 28,  50,  75],
#           [ 28,  50,  75],
#           ...,
#           [  8,  53, 114],
#           [  7,  53, 111],
#           [  6,  51, 112]]], dtype=uint8),
#   1]]

# %% [markdown]
# ## 2.2. Testing the model <a name="testowanie_modelu"></a>

# %% [markdown]
# I created functions to detect eyes and classify their state. The **add_margin_to_eye** function is used to expand the detection rectangle that contains the eye by adding margins to it. This allows for a larger area around the eye to be included. The **classify_eye_state** function is used to classify the eye state (open/closed) based on a given image fragment (ROI - Region of Interest). It takes the ROI image, processes it, and applies a predictive model to assess the eye state.

# %%
def add_margin_to_eye(x, y, w, h, width, height, margin_w=0.6, upper_margin_h=2.5, lower_margin_h=0.7):
    x_margin = int(w * margin_w)
    upper_y_margin = int(h * upper_margin_h)
    lower_y_margin = int(h * lower_margin_h)

    x_new = max(x - x_margin, 0)
    y_new = max(y - upper_y_margin, 0)
    x_end = min(x + w + x_margin, width)
    y_end = min(y + h + lower_y_margin, height)

    return (x_new, y_new, x_end - x_new, y_end - y_new)

def classify_eye_state(roi, model):
    roi_resized = cv2.resize(roi, (145, 145))
    roi_gray = cv2.cvtColor(roi_resized, cv2.COLOR_BGR2GRAY)
    roi_rgb = cv2.cvtColor(roi_gray, cv2.COLOR_GRAY2RGB)
    roi_normalized = roi_rgb / 255.0
    roi_expanded = np.expand_dims(roi_normalized, axis=0)
    prediction = model.predict(roi_expanded)
    return prediction[0]

# %% [markdown]
# I then wrote code to test the model on my dataset. It uses the dlib library to detect faces and determine key points on the face, and then uses the model to predict the eye state for each detected eye. The output is a list of predictions and file names, which are then analyzed to assess the model's accuracy by comparing it to the expected labels.

# %%
def process_folder(folder_path, expected_label, model):
    predictions = []
    filenames = []
    detector = dlib.get_frontal_face_detector()

    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)
        img = cv2.imread(image_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faceRects = detector(gray, 1)

        for (i, faceRect) in enumerate(faceRects):
            shape = predictor(gray, faceRect)
            shape_np = face_utils.shape_to_np(shape)

            for (name, (i, j)) in face_utils.FACIAL_LANDMARKS_IDXS.items():
                if name in ["left_eye", "right_eye"]:
                    (x, y, w, h) = cv2.boundingRect(np.array([shape_np[i:j]]))
                    (x, y, w, h) = add_margin_to_eye(x, y, w, h, img.shape[1], img.shape[0])

                    roi = img[y:y + h, x:x + w]
                    eye_state_prediction = classify_eye_state(roi, model)

                    eye_state = 1 if eye_state_prediction[0] > 0.5 else 0
                    predictions.append(eye_state)
                    filenames.append(image_name)

    return predictions, filenames

predictor = dlib.shape_predictor('..\shape_predictor_68_face_landmarks.dat')

eye_state_model = load_model('model_4.h5')

open_folder = r'..\output\captured_frames\open'
closed_folder = r'..\output\captured_frames\closed'

open_predictions, open_filenames = process_folder(open_folder, 0, eye_state_model)
closed_predictions, closed_filenames = process_folder(closed_folder, 1, eye_state_model)

predictions = open_predictions + closed_predictions
true_labels = [0] * len(open_predictions) + [1] * len(closed_predictions)
filenames = open_filenames + closed_filenames
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#               precision    recall  f1-score   support
#
#         Open       0.91      0.95      0.93       934
#       Closed       0.95      0.90      0.92       868
#
#     accuracy                           0.93      1802
#    macro avg       0.93      0.93      0.93      1802
# weighted avg       0.93      0.93      0.93      1802

# %%
print(classification_report(true_labels, predictions, target_names=['Open', 'Closed']))
# Out:
#               precision    recall  f1-score   support
#
#         Open       0.91      0.95      0.93       934
#       Closed       0.95      0.90      0.92       868
#
#     accuracy                           0.93      1802
#    macro avg       0.93      0.93      0.93      1802
# weighted avg       0.93      0.93      0.93      1802

# %% [markdown]
# ### Conclusions
# Recall for the 'Closed' class, the model's ability to correctly identify truly closed eyes, is 0.90. This is a key metric in the context of fatigue detection, as it is important that the system does not miss any cases where the driver's eyes are closed. Although a value of 90% is quite high, in ideal conditions, you would want to maximize this value to minimize the risk of missing a tired driver. The overall system accuracy is 0.93, meaning that 93% of the model's predictions are correct. This is a good value, indicating that the model is generally good at distinguishing between open and closed eyes.

# %% [markdown]
# ## 3. Testing the model on a video sequence <a name="testowanie_wideo"></a>

# %% [markdown]
# The final stage of the project was to use the created model in a situation simulating observing a driver in a car using an image captured by a laptop camera or previously recorded video.
#
# I wrote a code to monitor the user's eye state in real time. It uses the OpenCV library to read the video stream from the camera/video, and then analyzes each frame every 1 second to detect and assess the eye state (open or closed) using an eye state classification model.
#
# In each frame checked, the image is converted to grayscale, and then dlib methods are used to detect faces and key points that allow for eye localization. After eye regions are identified and framed using previously implemented functions, they are passed to the classify_eye_state function, which predicts whether the eye is open or closed.
#
# The system also monitors the duration of eye closure and if the eye remains closed for too long, a text alarm is generated to wake up, which is intended to prevent accidents caused by driver fatigue. The user can interrupt the program by pressing the 'q' key.

# %%
eye_state_model = load_model('model_4.h5')
detector = dlib.get_frontal_face_detector()

video_path = r'video_path'
cap = cv2.VideoCapture(video_path)
# cap = cv2.VideoCapture(0) # webcam

frame_counter = 0
check_interval = 30

closed_eye_counter = 0
closed_eye_threshold = 6
warning_display_time = 3
warning_end_time = None

window_width = 800
window_height = 480

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (window_width, window_height))

    frame_counter += 1

    if frame_counter % check_interval == 0:
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faceRects = detector(gray, 1)

        for (i, faceRect) in enumerate(faceRects):
            shape = predictor(gray, faceRect)
            shape_np = face_utils.shape_to_np(shape)

            for (name, (i, j)) in face_utils.FACIAL_LANDMARKS_IDXS.items():
                if name in ["left_eye", "right_eye"]:
                    (x, y, w, h) = cv2.boundingRect(np.array([shape_np[i:j]]))
                    (x, y, w, h) = add_margin_to_eye(x, y, w, h, frame.shape[1], frame.shape[0])

                    roi = frame[y:y + h, x:x + w]
                    eye_state_prediction = classify_eye_state(roi, eye_state_model)

                    if isinstance(eye_state_prediction, np.ndarray):
                        eye_state_probability = eye_state_prediction[0]
                    else:
                        eye_state_probability = eye_state_prediction

                    eye_state = "Open" if eye_state_probability < 0.5 else "Closed"
                    print(f"{name} state: {eye_state}")

                    if eye_state == "Closed":
                        closed_eye_counter += 1
                    else:
                        closed_eye_counter = 0

                    if closed_eye_counter >= closed_eye_threshold:
                        warning_end_time = time.time() + warning_display_time
                        closed_eye_counter = 0

    if warning_end_time and time.time() < warning_end_time:
        cv2.putText(frame, 'WARNING: Wake up!', (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 4, cv2.LINE_AA)

    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 4. Proposals for further development of the project <a name="rozwoj"></a>

# %% [markdown]
# * **Eye-point distance calculations**: Integrating this model with eye-point distance calculations could enable faster and more accurate detection of eye closure.
#
# * **Improving recall for the 'Closed' class**: To enhance the project's quality, efforts should focus on improving recall for the 'Closed' class. This could be achieved by further training the model on a larger dataset or by testing alternative neural network architectures that may be more effective for this task. Additionally, integrating this model with eye-point distance calculations could enable faster and more accurate detection of eye closure.
#
# * **Reducing the number of false alarms**: While safety is a priority and a higher number of alerts (even false ones) is acceptable, measures can be taken to minimize false alarms, making the system as user-friendly as possible.
#
# * **Enhancing the warning alert**: To regain the driver's attention, a simultaneous warning sound can be added alongside the text alert.
